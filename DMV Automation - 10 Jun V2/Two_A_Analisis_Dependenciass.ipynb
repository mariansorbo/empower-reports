# %% [markdown]
# # Este script sirve para obtener un análisis de dependencias entre columnas y métricas.
#
#
# # **INPUT** (Se obtiene de la Documentación de Reportes, o de la Documentación de Único Reporte, en una solapa con el mismo nombre):
# # '0 - Diccionario Columnas y Metricas - Reportes.csv'
#
# ------------------------
#
# # **OUTPUT** (Se usa en la Documentación de Reportes):
# # 2 - Analisis de Dependencias Intercolumnares - Reportes

# %%
import config_runtime
import config
usuario= config_runtime.usuario
reporte=config_runtime.reporte
path_carpeta =config.step1_extracciones_dmv

# %%
import os
import pandas as pd
import re
import import_ipynb
import Funciones  # debe contener la función estandarizar_y_unir


# Normalizar
usuario_norm = usuario.strip().lower()
reporte_norm = reporte.strip().lower()

# Inicializar
df_columnas = pd.DataFrame()
df_metricas = pd.DataFrame()
df_tablas = pd.DataFrame()

# Buscar archivos
for archivo in os.listdir(path_carpeta):
    if not archivo.endswith(".xlsx"):
        continue

    match = re.match(r"(.*?)\s*\+\s*(.*?)\s*\+\s*(.*?)\.xlsx", archivo)
    if not match:
        continue

    archivo_usuario, archivo_reporte, tipo = match.groups()
    tipo = tipo.strip().lower()

    if (archivo_usuario.strip().lower() == usuario_norm and
        archivo_reporte.strip().lower() == reporte_norm):

        filepath = os.path.join(path_carpeta, archivo)

        if tipo == "columnas":
            df_columnas = pd.read_excel(filepath)
            print(f"[OK] Cargado archivo de columnas: {archivo}")
        elif tipo == "metricas":
            df_metricas = pd.read_excel(filepath)
            print(f"[OK] Cargado archivo de métricas: {archivo}")
        elif tipo == "tablas":
            df_tablas = pd.read_excel(filepath)
            print(f"[OK] Cargado archivo de tablas: {archivo}")

# Unificar columnas + métricas
df_unificado = Funciones.estandarizar_y_unir(df_columnas, df_metricas)
# Out:
# [OK] Cargado archivo de columnas: testUser+Reporte de nutrición de Gonza 130+columnas.xlsx
# [OK] Cargado archivo de métricas: testUser+Reporte de nutrición de Gonza 130+metricas.xlsx
# [OK] Cargado archivo de tablas: testUser+Reporte de nutrición de Gonza 130+tablas.xlsx
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_unificado
# Out:
#                                Reporte   ID  TableID  \
# 0    Reporte de nutrición de Gonza 130   11       10
# 1    Reporte de nutrición de Gonza 130   83       10
# 2    Reporte de nutrición de Gonza 130   84       10
# 3    Reporte de nutrición de Gonza 130   85       10
# 4    Reporte de nutrición de Gonza 130   14       13
# ..                                 ...  ...      ...
# 276  Reporte de nutrición de Gonza 130  359       19
# 277  Reporte de nutrición de Gonza 130  360       19
# 278  Reporte de nutrición de Gonza 130  361       19
# 279  Reporte de nutrición de Gonza 130  362       22
# 280  Reporte de nutrición de Gonza 130  363       49
#
#                                                Name  IsHidden  DataType  \
# 0    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      True         3
# 1                                          Alimento      True         1
# 2                                  Unidad principal      True         1
# 3                        Equivalencia en gramos (g)      True         1
# 4    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      True         3
# ..                                              ...       ...       ...
# 276                           Consumo Alil-sulfuros     False         8
# 277                          Target - Alil-sulfuros     False         6
# 278                % Últimos 7 Días - Alil-sulfuros     False         8
# 279                                          Medida     False         6
# 280                                  ColorParametro     False         2
#
#                                             Expression  ModifiedTime  \
# 0                                                  NaN  45877.073077
# 1                                                  NaN  45877.073076
# 2                                                  NaN  45877.073076
# 3                                                  NaN  45877.073076
# 4                                                  NaN  45877.073077
# ..                                                 ...           ...
# 276  SUMX(\n    Consumos,\n    \n    VAR valorPor10...  45877.073091
# 277                         50 // Ejemplo: 50 mg\n      45877.073091
# 278  VAR FechaMax = MAX(Consumos[Timestamp])\n    V...  45877.073091
# 279                                                NaN  45877.073091
# 280  LOOKUPVALUE(\n    NutrientesColores[Color],\n ...  45877.073091
#
#      StructureModifiedTime                  DisplayFolder    Origen
# 0             45877.073076                            NaN  Columnas
# 1             45877.073076                            NaN  Columnas
# 2             45877.073076                            NaN  Columnas
# 3             45877.073076                            NaN  Columnas
# 4             45877.073076                            NaN  Columnas
# ..                     ...                            ...       ...
# 276           45877.073076        Consumo - Antioxidantes  Métricas
# 277           45877.073076  Target Diario - Antioxidantes  Métricas
# 278           45877.073076                            NaN  Métricas
# 279           45877.073076                            NaN  Métricas
# 280           45877.073076                            NaN  Métricas
#
# [281 rows x 11 columns]

# %%
# ✅ quiero traer el campo TableName, tengo Crear columna auxiliar en ambos DataFrames
df_unificado["join_key"] = df_unificado["Reporte"] + df_unificado["TableID"].astype(str)
df_tablas["join_key"] = df_tablas["Reporte"] + df_tablas["ID"].astype(str)

# ✅ Usar .map() para traer el campo 'Name' desde df_mariano_reporte_tablas
df_unificado["Tabla Nombre"] = df_unificado["join_key"].map(
    df_tablas.set_index("join_key")["Name"]
)


df_unificado
# Out:
#                                Reporte   ID  TableID  \
# 0    Reporte de nutrición de Gonza 130   11       10
# 1    Reporte de nutrición de Gonza 130   83       10
# 2    Reporte de nutrición de Gonza 130   84       10
# 3    Reporte de nutrición de Gonza 130   85       10
# 4    Reporte de nutrición de Gonza 130   14       13
# ..                                 ...  ...      ...
# 276  Reporte de nutrición de Gonza 130  359       19
# 277  Reporte de nutrición de Gonza 130  360       19
# 278  Reporte de nutrición de Gonza 130  361       19
# 279  Reporte de nutrición de Gonza 130  362       22
# 280  Reporte de nutrición de Gonza 130  363       49
#
#                                                Name  IsHidden  DataType  \
# 0    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      True         3
# 1                                          Alimento      True         1
# 2                                  Unidad principal      True         1
# 3                        Equivalencia en gramos (g)      True         1
# 4    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      True         3
# ..                                              ...       ...       ...
# 276                           Consumo Alil-sulfuros     False         8
# 277                          Target - Alil-sulfuros     False         6
# 278                % Últimos 7 Días - Alil-sulfuros     False         8
# 279                                          Medida     False         6
# 280                                  ColorParametro     False         2
#
#                                             Expression  ModifiedTime  \
# 0                                                  NaN  45877.073077
# 1                                                  NaN  45877.073076
# 2                                                  NaN  45877.073076
# 3                                                  NaN  45877.073076
# 4                                                  NaN  45877.073077
# ..                                                 ...           ...
# 276  SUMX(\n    Consumos,\n    \n    VAR valorPor10...  45877.073091
# 277                         50 // Ejemplo: 50 mg\n      45877.073091
# 278  VAR FechaMax = MAX(Consumos[Timestamp])\n    V...  45877.073091
# 279                                                NaN  45877.073091
# 280  LOOKUPVALUE(\n    NutrientesColores[Color],\n ...  45877.073091
#
#      StructureModifiedTime                  DisplayFolder    Origen  \
# 0             45877.073076                            NaN  Columnas
# 1             45877.073076                            NaN  Columnas
# 2             45877.073076                            NaN  Columnas
# 3             45877.073076                            NaN  Columnas
# 4             45877.073076                            NaN  Columnas
# ..                     ...                            ...       ...
# 276           45877.073076        Consumo - Antioxidantes  Métricas
# 277           45877.073076  Target Diario - Antioxidantes  Métricas
# 278           45877.073076                            NaN  Métricas
# 279           45877.073076                            NaN  Métricas
# 280           45877.073076                            NaN  Métricas
#
#                                 join_key Tabla Nombre
# 0    Reporte de nutrición de Gonza 13010    Porciones
# 1    Reporte de nutrición de Gonza 13010    Porciones
# 2    Reporte de nutrición de Gonza 13010    Porciones
# 3    Reporte de nutrición de Gonza 13010    Porciones
# 4    Reporte de nutrición de Gonza 13013    Minerales
# ..                                   ...          ...
# 276  Reporte de nutrición de Gonza 13019     Consumos
# 277  Reporte de nutrición de Gonza 13019     Consumos
# 278  Reporte de nutrición de Gonza 13019     Consumos
# 279  Reporte de nutrición de Gonza 13022    Alimentos
# 280  Reporte de nutrición de Gonza 13049   Nutrientes
#
# [281 rows x 13 columns]

# %%
# Definir función para extraer dependencias
def extraer_columnas(expresion, tabla_actual):
    # Buscar patrones de tipo dimension[columna] o [columna] en las expresiones
    patrones = re.findall(r'(\w*)\[(\w+)\]', expresion)
    columnas_referenciadas = []
    columnas_referenciadas_2=[]

    for dimension, columna in patrones:
        if dimension:  # Si hay un prefijo de dimensión
            columnas_referenciadas.append(f"{dimension}.{columna}")
        else:  # Si no hay prefijo de dimensión, pertenece a la tabla actual
            columnas_referenciadas.append(f"{tabla_actual}.{columna}")

    for dimension, columna in patrones:
        if dimension:  # Si hay un prefijo de dimensión
            columnas_referenciadas_2.append(f"{dimension}[{columna}]")
        else:  # Si no hay prefijo de dimensión, pertenece a la tabla actual
            columnas_referenciadas_2.append(f"{tabla_actual}[{columna}]")

    return columnas_referenciadas,columnas_referenciadas_2

# %%
# Construir diccionarios de dependencias y expresiones
dependencias = {}
dependencias_2 = {}  # Para las referencias con el formato de corchetes
expresiones = {}

for index, row in df_unificado.iterrows():
    reporte = row['Reporte']
    tabla = row['Tabla Nombre']
    columna = row['Name']
    tabla_columna = f"{tabla}|{columna}"
    print(  reporte,tabla,columna,tabla_columna)
    if reporte not in dependencias:
        dependencias[reporte] = {}
        dependencias_2[reporte] = {}  # Inicializar para dependencias_2
        expresiones[reporte] = {}

    if pd.notna(row['Expression']):
        columnas_referenciadas, columnas_referenciadas_2 = extraer_columnas(row['Expression'], tabla)

        if tabla_columna not in dependencias[reporte]:
            dependencias[reporte][tabla_columna] = []
            dependencias_2[reporte][tabla_columna] = []  # Para dependencias_2

        dependencias[reporte][tabla_columna].extend(columnas_referenciadas)
        dependencias_2[reporte][tabla_columna].extend(columnas_referenciadas_2)  # Para dependencias_2
        expresiones[reporte][tabla_columna] = row['Expression']
    else:
        expresiones[reporte][tabla_columna] = None  # Marca para columnas no calculadas
        dependencias[reporte][tabla_columna] = []  # No tiene dependencias si es directa
        dependencias_2[reporte][tabla_columna] = []  # No tiene dependencias si es directa
# Out:
# Reporte de nutrición de Gonza 130 Porciones RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Porciones|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Porciones Alimento Porciones|Alimento
# Reporte de nutrición de Gonza 130 Porciones Unidad principal Porciones|Unidad principal
# Reporte de nutrición de Gonza 130 Porciones Equivalencia en gramos (g) Porciones|Equivalencia en gramos (g)
# Reporte de nutrición de Gonza 130 Minerales RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Minerales|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Minerales Alimento Minerales|Alimento
# Reporte de nutrición de Gonza 130 Minerales Calcio (mg) Minerales|Calcio (mg)
# Reporte de nutrición de Gonza 130 Minerales Hierro (mg) Minerales|Hierro (mg)
# Reporte de nutrición de Gonza 130 Minerales Magnesio (mg) Minerales|Magnesio (mg)
# Reporte de nutrición de Gonza 130 Minerales Potasio (mg) Minerales|Potasio (mg)
# Reporte de nutrición de Gonza 130 Minerales Sodio (mg) Minerales|Sodio (mg)
# Reporte de nutrición de Gonza 130 Minerales Zinc (mg) Minerales|Zinc (mg)
# Reporte de nutrición de Gonza 130 Minerales Selenio (µg) Minerales|Selenio (µg)
# Reporte de nutrición de Gonza 130 Grasas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Grasas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Grasas Alimento Grasas|Alimento
# Reporte de nutrición de Gonza 130 Grasas Grasas Totales (g) Grasas|Grasas Totales (g)
# Reporte de nutrición de Gonza 130 Grasas Saturadas (g) Grasas|Saturadas (g)
# Reporte de nutrición de Gonza 130 Grasas Monoinsaturadas (g) Grasas|Monoinsaturadas (g)
# Reporte de nutrición de Gonza 130 Grasas Poliinsaturadas (g) Grasas|Poliinsaturadas (g)
# Reporte de nutrición de Gonza 130 Grasas Trans (g) Grasas|Trans (g)
# Reporte de nutrición de Gonza 130 Grasas Omega-3 (g) Grasas|Omega-3 (g)
# Reporte de nutrición de Gonza 130 Grasas Omega-6 (g) Grasas|Omega-6 (g)
# Reporte de nutrición de Gonza 130 Grasas Omega-9 (g) Grasas|Omega-9 (g)
# Reporte de nutrición de Gonza 130 Consumos RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Consumos|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Consumos Alimento Consumos|Alimento
# Reporte de nutrición de Gonza 130 Consumos Cantidad (gr) Consumos|Cantidad (gr)
# Reporte de nutrición de Gonza 130 Consumos Unidades Consumos|Unidades
# Reporte de nutrición de Gonza 130 Consumos Timestamp Consumos|Timestamp
# Reporte de nutrición de Gonza 130 Consumos Date Consumos|Date
# Reporte de nutrición de Gonza 130 Consumos Consumo Proteinas Consumos|Consumo Proteinas
# Reporte de nutrición de Gonza 130 Consumos Consumo Carbohidratos Consumos|Consumo Carbohidratos
# Reporte de nutrición de Gonza 130 Consumos Consumo Grasas Consumos|Consumo Grasas
# Reporte de nutrición de Gonza 130 Consumos Consumo Azúcares Consumos|Consumo Azúcares
# Reporte de nutrición de Gonza 130 Consumos Consumo Fibra Consumos|Consumo Fibra
# Reporte de nutrición de Gonza 130 Consumos Cantidad* Consumos|Cantidad*
# Reporte de nutrición de Gonza 130 Consumos Date* Consumos|Date*
# Reporte de nutrición de Gonza 130 Consumos Consumo Calorías Consumos|Consumo Calorías
# Reporte de nutrición de Gonza 130 Consumos date** Consumos|date**
# Reporte de nutrición de Gonza 130 Consumos Consumo Formateado Consumos|Consumo Formateado
# Reporte de nutrición de Gonza 130 Consumos Alimento Corrected Consumos|Alimento Corrected
# Reporte de nutrición de Gonza 130 Consumos Comentario Consumos|Comentario
# Reporte de nutrición de Gonza 130 Consumos Usuario Consumos|Usuario
# Reporte de nutrición de Gonza 130 Alimentos RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Alimentos|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Alimentos Alimento Alimentos|Alimento
# Reporte de nutrición de Gonza 130 Alimentos Tipo Alimentos|Tipo
# Reporte de nutrición de Gonza 130 Alimentos Categoría Alimentos|Categoría
# Reporte de nutrición de Gonza 130 Alimentos Calorías (kcal/100g) Alimentos|Calorías (kcal/100g)
# Reporte de nutrición de Gonza 130 Alimentos Unidad principal Alimentos|Unidad principal
# Reporte de nutrición de Gonza 130 Alimentos Gramos por unidad (promedio) Alimentos|Gramos por unidad (promedio)
# Reporte de nutrición de Gonza 130 Alimentos Etiqueta Calórica Alimentos|Etiqueta Calórica
# Reporte de nutrición de Gonza 130 Alimentos Column1 Alimentos|Column1
# Reporte de nutrición de Gonza 130 Alimentos Sinonimos Alimentos|Sinonimos
# Reporte de nutrición de Gonza 130 Alimentos Comentario Alimentos|Comentario
# Reporte de nutrición de Gonza 130 Alimentos Alimento* Alimentos|Alimento*
# Reporte de nutrición de Gonza 130 Carbohidratos RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Carbohidratos|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Carbohidratos Alimento Carbohidratos|Alimento
# Reporte de nutrición de Gonza 130 Carbohidratos Carbohidratos totales (g) Carbohidratos|Carbohidratos totales (g)
# Reporte de nutrición de Gonza 130 Carbohidratos Almidón (g) Carbohidratos|Almidón (g)
# Reporte de nutrición de Gonza 130 Carbohidratos Índice glucémico (IG) Carbohidratos|Índice glucémico (IG)
# Reporte de nutrición de Gonza 130 Carbohidratos Carga glucémica (CG) Carbohidratos|Carga glucémica (CG)
# Reporte de nutrición de Gonza 130 Carbohidratos Rango IG Carbohidratos|Rango IG
# Reporte de nutrición de Gonza 130 Proteinas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Proteinas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Proteinas Alimento Proteinas|Alimento
# Reporte de nutrición de Gonza 130 Proteinas Tipo Proteinas|Tipo
# Reporte de nutrición de Gonza 130 Proteinas Proteínas (g) Proteinas|Proteínas (g)
# Reporte de nutrición de Gonza 130 Proteinas Lisina Proteinas|Lisina
# Reporte de nutrición de Gonza 130 Proteinas Metionina Proteinas|Metionina
# Reporte de nutrición de Gonza 130 Proteinas Leucina Proteinas|Leucina
# Reporte de nutrición de Gonza 130 Proteinas Valina Proteinas|Valina
# Reporte de nutrición de Gonza 130 Proteinas Isoleucina Proteinas|Isoleucina
# Reporte de nutrición de Gonza 130 Proteinas Treonina Proteinas|Treonina
# Reporte de nutrición de Gonza 130 Proteinas Fenilalanina Proteinas|Fenilalanina
# Reporte de nutrición de Gonza 130 Proteinas Triptófano Proteinas|Triptófano
# Reporte de nutrición de Gonza 130 Proteinas Histidina Proteinas|Histidina
# Reporte de nutrición de Gonza 130 Vitaminas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Vitaminas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Vitaminas Alimento Vitaminas|Alimento
# Reporte de nutrición de Gonza 130 Vitaminas Vitamina A (µg) Vitaminas|Vitamina A (µg)
# Reporte de nutrición de Gonza 130 Vitaminas Vitamina C (mg) Vitaminas|Vitamina C (mg)
# Reporte de nutrición de Gonza 130 Vitaminas Vitamina D (µg) Vitaminas|Vitamina D (µg)
# Reporte de nutrición de Gonza 130 Vitaminas Vitamina E (mg) Vitaminas|Vitamina E (mg)
# Reporte de nutrición de Gonza 130 Vitaminas Vitamina K (µg) Vitaminas|Vitamina K (µg)
# Reporte de nutrición de Gonza 130 Vitaminas B1 (mg) Vitaminas|B1 (mg)
# Reporte de nutrición de Gonza 130 Vitaminas B2 (mg) Vitaminas|B2 (mg)
# Reporte de nutrición de Gonza 130 Vitaminas B6 (mg) Vitaminas|B6 (mg)
# Reporte de nutrición de Gonza 130 Vitaminas B12 (µg) Vitaminas|B12 (µg)
# Reporte de nutrición de Gonza 130 Iconos RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Iconos|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Iconos Alimento Iconos|Alimento
# Reporte de nutrición de Gonza 130 Iconos Ícono Iconos|Ícono
# Reporte de nutrición de Gonza 130 Calendario RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Calendario|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Calendario nan Calendario|nan
# Reporte de nutrición de Gonza 130 Calendario nan Calendario|nan
# Reporte de nutrición de Gonza 130 Calendario nan Calendario|nan
# Reporte de nutrición de Gonza 130 Calendario nan Calendario|nan
# Reporte de nutrición de Gonza 130 Calendario nan Calendario|nan
# Reporte de nutrición de Gonza 130 Calendario Datemonth Calendario|Datemonth
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 nan DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|nan
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 Año DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|Año
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 NroMes DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|NroMes
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 Mes DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|Mes
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 NroTrimestre DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|NroTrimestre
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 Trimestre DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|Trimestre
# Reporte de nutrición de Gonza 130 DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31 Día DateTableTemplate_2819b910-27a8-42ae-97f4-206566172f31|Día
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 nan LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|nan
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 Año LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|Año
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 NroMes LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|NroMes
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 Mes LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|Mes
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 NroTrimestre LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|NroTrimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 Trimestre LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|Trimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070 Día LocalDateTable_5bbabe0b-35db-4111-bdb1-acd1caf79070|Día
# Reporte de nutrición de Gonza 130 NutrientesColores RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 NutrientesColores|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 NutrientesColores nan NutrientesColores|nan
# Reporte de nutrición de Gonza 130 NutrientesColores nan NutrientesColores|nan
# Reporte de nutrición de Gonza 130 Nutrientes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Nutrientes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Nutrientes Nutrientes Nutrientes|Nutrientes
# Reporte de nutrición de Gonza 130 Nutrientes Nutrientes Campos Nutrientes|Nutrientes Campos
# Reporte de nutrición de Gonza 130 Nutrientes Nutrientes Orden Nutrientes|Nutrientes Orden
# Reporte de nutrición de Gonza 130 Azucares RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Azucares|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Azucares Alimento Azucares|Alimento
# Reporte de nutrición de Gonza 130 Azucares Azucares (g) Azucares|Azucares (g)
# Reporte de nutrición de Gonza 130 Azucares Glucosa (g) Azucares|Glucosa (g)
# Reporte de nutrición de Gonza 130 Azucares Fructosa (g) Azucares|Fructosa (g)
# Reporte de nutrición de Gonza 130 Azucares Galactosa (g) Azucares|Galactosa (g)
# Reporte de nutrición de Gonza 130 Azucares Sacarosa (g) Azucares|Sacarosa (g)
# Reporte de nutrición de Gonza 130 Azucares Lactosa (g) Azucares|Lactosa (g)
# Reporte de nutrición de Gonza 130 Azucares Maltosa (g) Azucares|Maltosa (g)
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 nan LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|nan
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 Año LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|Año
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 NroMes LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|NroMes
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 Mes LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|Mes
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 NroTrimestre LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|NroTrimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 Trimestre LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|Trimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328 Día LocalDateTable_84adb19b-de7b-4f43-8f49-e199c11aa328|Día
# Reporte de nutrición de Gonza 130 Fibras RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Fibras|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Fibras Alimento Fibras|Alimento
# Reporte de nutrición de Gonza 130 Fibras Fibra Total (g/100g) Fibras|Fibra Total (g/100g)
# Reporte de nutrición de Gonza 130 Fibras Fibra Soluble (g) Fibras|Fibra Soluble (g)
# Reporte de nutrición de Gonza 130 Fibras Fibra Insoluble (g) Fibras|Fibra Insoluble (g)
# Reporte de nutrición de Gonza 130 Fibras Fermentabilidad Fibras|Fermentabilidad
# Reporte de nutrición de Gonza 130 Fibras Tipo de Fibra Dominante Fibras|Tipo de Fibra Dominante
# Reporte de nutrición de Gonza 130 Fibras Función Digestiva Principal Fibras|Función Digestiva Principal
# Reporte de nutrición de Gonza 130 Fibras Fibra Resistente (%) Fibras|Fibra Resistente (%)
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 nan LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|nan
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 Año LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|Año
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 NroMes LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|NroMes
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 Mes LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|Mes
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 NroTrimestre LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|NroTrimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 Trimestre LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|Trimestre
# Reporte de nutrición de Gonza 130 LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51 Día LocalDateTable_0011bf27-91a3-4694-93e2-f75d33780c51|Día
# Reporte de nutrición de Gonza 130 Antioxidantes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Antioxidantes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Reporte de nutrición de Gonza 130 Antioxidantes Alimento Antioxidantes|Alimento
# Reporte de nutrición de Gonza 130 Antioxidantes Betacaroteno (µg) Antioxidantes|Betacaroteno (µg)
# Reporte de nutrición de Gonza 130 Antioxidantes Licopeno (µg) Antioxidantes|Licopeno (µg)
# Reporte de nutrición de Gonza 130 Antioxidantes Luteína + Zeaxantina (µg) Antioxidantes|Luteína + Zeaxantina (µg)
# Reporte de nutrición de Gonza 130 Antioxidantes Quercetina (mg) Antioxidantes|Quercetina (mg)
# Reporte de nutrición de Gonza 130 Antioxidantes Catequinas (mg) Antioxidantes|Catequinas (mg)
# Reporte de nutrición de Gonza 130 Antioxidantes Ácido elágico (mg) Antioxidantes|Ácido elágico (mg)
# Reporte de nutrición de Gonza 130 Antioxidantes Resveratrol (mg) Antioxidantes|Resveratrol (mg)
# Reporte de nutrición de Gonza 130 Antioxidantes Sulforafano (µmol) Antioxidantes|Sulforafano (µmol)
# Reporte de nutrición de Gonza 130 Antioxidantes Alil-sulfuros (mg) Antioxidantes|Alil-sulfuros (mg)
# Reporte de nutrición de Gonza 130 Consumos *Consumo Proteinas Consumos|*Consumo Proteinas
# Reporte de nutrición de Gonza 130 Consumos *Consumo Carbohidratos Consumos|*Consumo Carbohidratos
# Reporte de nutrición de Gonza 130 Consumos *Consumo Grasas Consumos|*Consumo Grasas
# Reporte de nutrición de Gonza 130 Consumos *Consumo Azúcares Consumos|*Consumo Azúcares
# Reporte de nutrición de Gonza 130 Consumos *Consumo Fibra Consumos|*Consumo Fibra
# Reporte de nutrición de Gonza 130 Consumos *Consumo Calorías Consumos|*Consumo Calorías
# Reporte de nutrición de Gonza 130 Consumos **ConsumoGrasaMonoinsaturada Consumos|**ConsumoGrasaMonoinsaturada
# Reporte de nutrición de Gonza 130 Consumos **ConsumoGrasaPoliinsaturada Consumos|**ConsumoGrasaPoliinsaturada
# Reporte de nutrición de Gonza 130 Consumos **ConsumoGrasaSaturada Consumos|**ConsumoGrasaSaturada
# Reporte de nutrición de Gonza 130 Consumos **Consumo Omega3 Consumos|**Consumo Omega3
# Reporte de nutrición de Gonza 130 Consumos **Consumo Omega6 Consumos|**Consumo Omega6
# Reporte de nutrición de Gonza 130 Consumos **Consumo Omega9 Consumos|**Consumo Omega9
# Reporte de nutrición de Gonza 130 Consumos % Calorías Proteínas Consumos|% Calorías Proteínas
# Reporte de nutrición de Gonza 130 Consumos % Calorías Grasas Consumos|% Calorías Grasas
# Reporte de nutrición de Gonza 130 Consumos % Calorías Azúcares Consumos|% Calorías Azúcares
# Reporte de nutrición de Gonza 130 Consumos % Calorías Carbohidratos Consumos|% Calorías Carbohidratos
# Reporte de nutrición de Gonza 130 Consumos % Calorías Fibra Consumos|% Calorías Fibra
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina C Consumos|Consumo Vitamina C
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina E Consumos|Consumo Vitamina E
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina A Consumos|Consumo Vitamina A
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina K Consumos|Consumo Vitamina K
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina B1 Consumos|Consumo Vitamina B1
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina B12 Consumos|Consumo Vitamina B12
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina B2 Consumos|Consumo Vitamina B2
# Reporte de nutrición de Gonza 130 Consumos Consumo Vitamina B6 Consumos|Consumo Vitamina B6
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina A Consumos|% Últimos 7 Días - Vitamina A
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina B1 Consumos|% Últimos 7 Días - Vitamina B1
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina B2 Consumos|% Últimos 7 Días - Vitamina B2
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina B6 Consumos|% Últimos 7 Días - Vitamina B6
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina B12 Consumos|% Últimos 7 Días - Vitamina B12
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina C Consumos|% Últimos 7 Días - Vitamina C
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina E Consumos|% Últimos 7 Días - Vitamina E
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Vitamina K Consumos|% Últimos 7 Días - Vitamina K
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina C Consumos|Target - Vitamina C
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina A Consumos|Target - Vitamina A
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina B1 Consumos|Target - Vitamina B1
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina B2 Consumos|Target - Vitamina B2
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina B6 Consumos|Target - Vitamina B6
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina B12 Consumos|Target - Vitamina B12
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina E Consumos|Target - Vitamina E
# Reporte de nutrición de Gonza 130 Consumos Target - Vitamina K Consumos|Target - Vitamina K
# Reporte de nutrición de Gonza 130 Consumos Target - Proteínas Consumos|Target - Proteínas
# Reporte de nutrición de Gonza 130 Consumos Target - Grasas Consumos|Target - Grasas
# Reporte de nutrición de Gonza 130 Consumos Target - Carbohidratos Consumos|Target - Carbohidratos
# Reporte de nutrición de Gonza 130 Consumos Target - Azúcares Consumos|Target - Azúcares
# Reporte de nutrición de Gonza 130 Consumos Target - Fibra Consumos|Target - Fibra
# Reporte de nutrición de Gonza 130 Consumos Target - Calorías Consumos|Target - Calorías
# Reporte de nutrición de Gonza 130 Consumos Aporte Vitamina Seleccionada Consumos|Aporte Vitamina Seleccionada
# Reporte de nutrición de Gonza 130 Consumos Total Gramos por Alimento Consumos|Total Gramos por Alimento
# Reporte de nutrición de Gonza 130 Consumos Consumo Glucosa Consumos|Consumo Glucosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Fructosa Consumos|Consumo Fructosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Galactosa Consumos|Consumo Galactosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Sacarosa Consumos|Consumo Sacarosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Lactosa Consumos|Consumo Lactosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Maltosa Consumos|Consumo Maltosa
# Reporte de nutrición de Gonza 130 Consumos Consumo Fibra2 Consumos|Consumo Fibra2
# Reporte de nutrición de Gonza 130 Consumos Consumo Fibra Soluble Consumos|Consumo Fibra Soluble
# Reporte de nutrición de Gonza 130 Consumos Consumo Fibra Insoluble Consumos|Consumo Fibra Insoluble
# Reporte de nutrición de Gonza 130 Consumos Carga Glucémica Total Consumos|Carga Glucémica Total
# Reporte de nutrición de Gonza 130 Consumos Consumo Almidón Consumos|Consumo Almidón
# Reporte de nutrición de Gonza 130 Consumos Consumo Histidina Consumos|Consumo Histidina
# Reporte de nutrición de Gonza 130 Consumos Consumo Leucina Consumos|Consumo Leucina
# Reporte de nutrición de Gonza 130 Consumos Consumo Lisina Consumos|Consumo Lisina
# Reporte de nutrición de Gonza 130 Consumos Consumo Metionina Consumos|Consumo Metionina
# Reporte de nutrición de Gonza 130 Consumos Consumo Valina Consumos|Consumo Valina
# Reporte de nutrición de Gonza 130 Consumos Consumo Treonina Consumos|Consumo Treonina
# Reporte de nutrición de Gonza 130 Consumos Consumo Triptófano Consumos|Consumo Triptófano
# Reporte de nutrición de Gonza 130 Consumos Consumo Isoleucina Consumos|Consumo Isoleucina
# Reporte de nutrición de Gonza 130 Consumos Consumo Calcio Consumos|Consumo Calcio
# Reporte de nutrición de Gonza 130 Consumos Consumo Hierro Consumos|Consumo Hierro
# Reporte de nutrición de Gonza 130 Consumos Consumo Magnesio Consumos|Consumo Magnesio
# Reporte de nutrición de Gonza 130 Consumos Consumo Zinc Consumos|Consumo Zinc
# Reporte de nutrición de Gonza 130 Consumos Consumo Potasio Consumos|Consumo Potasio
# Reporte de nutrición de Gonza 130 Consumos Consumo Sodio Consumos|Consumo Sodio
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Calcio Consumos|Target Diario - Calcio
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Hierro Consumos|Target Diario - Hierro
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Magnesio Consumos|Target Diario - Magnesio
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Fósforo Consumos|Target Diario - Fósforo
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Potasio Consumos|Target Diario - Potasio
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Zinc Consumos|Target Diario - Zinc
# Reporte de nutrición de Gonza 130 Consumos Target Diario - Sodio Consumos|Target Diario - Sodio
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Calcio Consumos|% Últimos 7 Días - Calcio
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Hierro Consumos|% Últimos 7 Días - Hierro
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Magnesio Consumos|% Últimos 7 Días - Magnesio
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Fósforo Consumos|% Últimos 7 Días - Fósforo
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Potasio Consumos|% Últimos 7 Días - Potasio
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Zinc Consumos|% Últimos 7 Días - Zinc
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Sodio Consumos|% Últimos 7 Días - Sodio
# Reporte de nutrición de Gonza 130 Consumos Total Gramos Por Alimento* Consumos|Total Gramos Por Alimento*
# Reporte de nutrición de Gonza 130 Consumos Consumo Licopeno Consumos|Consumo Licopeno
# Reporte de nutrición de Gonza 130 Consumos Target - Licopeno Consumos|Target - Licopeno
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Licopeno Consumos|% Últimos 7 Días - Licopeno
# Reporte de nutrición de Gonza 130 Consumos Consumo Betacaroteno Consumos|Consumo Betacaroteno
# Reporte de nutrición de Gonza 130 Consumos Target - Betacaroteno Consumos|Target - Betacaroteno
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Betacaroteno Consumos|% Últimos 7 Días - Betacaroteno
# Reporte de nutrición de Gonza 130 Consumos Consumo Luteina + Zeaxantina Consumos|Consumo Luteina + Zeaxantina
# Reporte de nutrición de Gonza 130 Consumos Target - Luteina + Zeaxantina Consumos|Target - Luteina + Zeaxantina
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Luteina + Zeaxantina Consumos|% Últimos 7 Días - Luteina + Zeaxantina
# Reporte de nutrición de Gonza 130 Consumos Consumo Quercetina Consumos|Consumo Quercetina
# Reporte de nutrición de Gonza 130 Consumos Target - Quercetina Consumos|Target - Quercetina
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Quercetina Consumos|% Últimos 7 Días - Quercetina
# Reporte de nutrición de Gonza 130 Consumos Consumo Catequinas Consumos|Consumo Catequinas
# Reporte de nutrición de Gonza 130 Consumos Target - Catequinas Consumos|Target - Catequinas
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Catequinas Consumos|% Últimos 7 Días - Catequinas
# Reporte de nutrición de Gonza 130 Consumos Consumo Acido Elagico Consumos|Consumo Acido Elagico
# Reporte de nutrición de Gonza 130 Consumos Target - Acido Elagico Consumos|Target - Acido Elagico
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Acido Elagico Consumos|% Últimos 7 Días - Acido Elagico
# Reporte de nutrición de Gonza 130 Consumos Consumo Resveratrol Consumos|Consumo Resveratrol
# Reporte de nutrición de Gonza 130 Consumos Target - Resveratrol Consumos|Target - Resveratrol
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Resveratrol Consumos|% Últimos 7 Días - Resveratrol
# Reporte de nutrición de Gonza 130 Consumos Consumo Sulforafano Consumos|Consumo Sulforafano
# Reporte de nutrición de Gonza 130 Consumos Target - Sulforafano Consumos|Target - Sulforafano
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Sulforafano Consumos|% Últimos 7 Días - Sulforafano
# Reporte de nutrición de Gonza 130 Consumos Consumo Alil-sulfuros Consumos|Consumo Alil-sulfuros
# Reporte de nutrición de Gonza 130 Consumos Target - Alil-sulfuros Consumos|Target - Alil-sulfuros
# Reporte de nutrición de Gonza 130 Consumos % Últimos 7 Días - Alil-sulfuros Consumos|% Últimos 7 Días - Alil-sulfuros
# Reporte de nutrición de Gonza 130 Alimentos Medida Alimentos|Medida
# Reporte de nutrición de Gonza 130 Nutrientes ColorParametro Nutrientes|ColorParametro

# %%
# Crear el DataFrame final con las columnas solicitadas
data = []

for reporte in dependencias:
    for tabla_columna in dependencias[reporte]:
        try:
            # Safely split into tabla and columna
            tabla, columna = tabla_columna.split("|", maxsplit=1)  # Use maxsplit to avoid extra splits
        except ValueError:
            # Handle cases where the split doesn't produce exactly two parts
            print(f"Warning: Unexpected format in 'tabla_columna': {tabla_columna}")
            tabla, columna = tabla_columna, None  # Assign defaults

        expresion = expresiones[reporte].get(tabla_columna)
        referencias = dependencias[reporte][tabla_columna]
        referencias_2 = dependencias_2[reporte].get(tabla_columna, [])  # Handle missing keys in dependencias_2

        # Determine if it is final
        es_final = 'Si' if expresion is None else 'No'

        # Add the row to the new DataFrame
        data.append({
            'reporte': reporte,
            'Tabla Nombre': tabla,
            'Columna Nombre': columna,
            'Expresión': expresion,
            'Referencias': referencias,
            'Referencias 2': ",".join(referencias_2),  # Join the list as a single string
            'Es Final': es_final
        })

# Crear el DataFrame
df_resultado = pd.DataFrame(data)

# Mostrar los primeros 20 registros para verificar
df_resultado.head(20)
# Out:
#                               reporte Tabla Nombre  \
# 0   Reporte de nutrición de Gonza 130    Porciones
# 1   Reporte de nutrición de Gonza 130    Porciones
# 2   Reporte de nutrición de Gonza 130    Porciones
# 3   Reporte de nutrición de Gonza 130    Porciones
# 4   Reporte de nutrición de Gonza 130    Minerales
# 5   Reporte de nutrición de Gonza 130    Minerales
# 6   Reporte de nutrición de Gonza 130    Minerales
# 7   Reporte de nutrición de Gonza 130    Minerales
# 8   Reporte de nutrición de Gonza 130    Minerales
# 9   Reporte de nutrición de Gonza 130    Minerales
# 10  Reporte de nutrición de Gonza 130    Minerales
# 11  Reporte de nutrición de Gonza 130    Minerales
# 12  Reporte de nutrición de Gonza 130    Minerales
# 13  Reporte de nutrición de Gonza 130       Grasas
# 14  Reporte de nutrición de Gonza 130       Grasas
# 15  Reporte de nutrición de Gonza 130       Grasas
# 16  Reporte de nutrición de Gonza 130       Grasas
# 17  Reporte de nutrición de Gonza 130       Grasas
# 18  Reporte de nutrición de Gonza 130       Grasas
# 19  Reporte de nutrición de Gonza 130       Grasas
#
#                                     Columna Nombre Expresión Referencias  \
# 0   RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      None          []
# 1                                         Alimento      None          []
# 2                                 Unidad principal      None          []
# 3                       Equivalencia en gramos (g)      None          []
# 4   RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      None          []
# 5                                         Alimento      None          []
# 6                                      Calcio (mg)      None          []
# 7                                      Hierro (mg)      None          []
# 8                                    Magnesio (mg)      None          []
# 9                                     Potasio (mg)      None          []
# 10                                      Sodio (mg)      None          []
# 11                                       Zinc (mg)      None          []
# 12                                    Selenio (µg)      None          []
# 13  RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      None          []
# 14                                        Alimento      None          []
# 15                              Grasas Totales (g)      None          []
# 16                                   Saturadas (g)      None          []
# 17                             Monoinsaturadas (g)      None          []
# 18                             Poliinsaturadas (g)      None          []
# 19                                       Trans (g)      None          []
#
#    Referencias 2 Es Final
# 0                      Si
# 1                      Si
# 2                      Si
# 3                      Si
# 4                      Si
# 5                      Si
# 6                      Si
# 7                      Si
# 8                      Si
# 9                      Si
# 10                     Si
# 11                     Si
# 12                     Si
# 13                     Si
# 14                     Si
# 15                     Si
# 16                     Si
# 17                     Si
# 18                     Si
# 19                     Si

# %%
from collections.abc import Iterable

# Función que devuelve la expresión de la columna a partir del reporte, tabla y columna
def ObtenerExpresion(df_resultado, reporte, tabla, columna):
    # Filtrar el DataFrame para obtener la expresión de la columna actual
    fila_actual = df_resultado[
        (df_resultado['reporte'] == reporte) &
        (df_resultado['Tabla Nombre'] == tabla) &
        (df_resultado['Columna Nombre'] == columna)
    ]

    # Si se encuentra la fila, devolver la expresión, si no, devolver un mensaje indicando que no se encontró
    if not fila_actual.empty:
        return fila_actual.iloc[0]['Expresión']
    else:
        return "Expresión no encontrada para la columna especificada."

# Función que devuelve un array de referencias a partir del reporte, tabla y columna
def obtener_referencias(df_resultado, reporte, tabla, columna):
    # Filtrar el DataFrame para obtener las dependencias de la columna actual
    fila_actual = df_resultado[
        (df_resultado['reporte'] == reporte) &
        (df_resultado['Tabla Nombre'] == tabla) &
        (df_resultado['Columna Nombre'] == columna)
    ]

    # Si se encuentra la fila, devolver las referencias, si no, devolver un array vacío
    if not fila_actual.empty:
        return list(set(fila_actual.iloc[0]['Referencias']))
    else:
        return None

# Función que devuelve las referencias en formato "dimension[columna]"
def obtener_referencias_2(df_resultado, reporte, tabla, columna):
    # Filtrar el DataFrame para obtener las dependencias formateadas en "Referencias 2"
    fila_actual = df_resultado[
        (df_resultado['reporte'] == reporte) &
        (df_resultado['Tabla Nombre'] == tabla) &
        (df_resultado['Columna Nombre'] == columna)
    ]

    # Si se encuentra la fila, devolver las referencias 2, si no, devolver un array vacío
    if not fila_actual.empty:
        return list(set(fila_actual.iloc[0]['Referencias 2']))
    else:
        return None

# Función recursiva para analizar las dependencias entre columnas y devolver el análisis y las columnas finales
def Recursividad(reporte, tabla, columna, nivel=1, visitados=None, columnasFinales=None, analisis="", lista_columnas_finales=None):
    sangria="          "
    if nivel >= 10:
        return analisis  # Retorna el análisis si el nivel es muy alto


    # Inicializar los parámetros opcionales si son None
    if visitados is None:
        visitados = set()  # Para controlar los nodos ya visitados y evitar bucles
    if columnasFinales is None:
        columnasFinales = set()  # Lista de columnas finales (que no tienen dependencias)
    if lista_columnas_finales is None:
        lista_columnas_finales = []  # Lista para acumular las columnas finales

    # Definir la clave única para la columna actual (tabla.columna)
    clave_columna = f"{tabla}[{columna}]"

    # Caso base: Si la columna ya fue visitada o si es una columna final, terminar la recursividad
    if clave_columna in visitados or clave_columna in columnasFinales:
        return analisis

    # Marcar la columna como visitada
    visitados.add(clave_columna)

    # Obtener su expresión o lógica
    expresion_actual = ObtenerExpresion(df_resultado, reporte, tabla, columna)

    # Obtener las dependencias (referencias a otras columnas) de la columna actual
    dependencias_actuales = obtener_referencias(df_resultado, reporte, tabla, columna)
    dependencias_actuales_2 = obtener_referencias_2(df_resultado, reporte, tabla, columna)  # Obtener referencias 2

    # Agregar información de la columna actual al análisis
    if dependencias_actuales is not None and isinstance(expresion_actual, Iterable):
        try:
            analisis +=      f"Nivel {nivel}:\n"
            analisis +=   f"{clave_columna}=\n"
            analisis +=   f"{expresion_actual}\n"
            analisis +=    f"--Columnas Referenciadas : {', '.join(dependencias_actuales)}\n\n"
        except Exception as e:
            analisis += f"Error procesando {clave_columna}: {str(e)}\n"
            columnasFinales.add(clave_columna)
            lista_columnas_finales.append(clave_columna)
    else:
        # Columnas sin dependencias (finales)
        columnasFinales.add(clave_columna)
        lista_columnas_finales.append(clave_columna)

    # Recorrer las dependencias de la columna y llamar recursivamente
    for referencia in dependencias_actuales or []:
        # Verificar si la referencia sigue el formato "tabla.columna"
        if '.' in referencia:
            tabla_ref, columna_ref = referencia.split('.')
            analisis = Recursividad(reporte, tabla_ref, columna_ref, nivel + 1, visitados, columnasFinales, analisis, lista_columnas_finales)
        else:
            analisis += f"Error: referencia '{referencia}' no tiene formato 'tabla.columna'.\n"

    return analisis

# Ejemplo de uso:
reporte_ejemplo = 'COC and COI'
tabla_ejemplo = 'HR Headcount'
columna_ejemplo = '# Trámites 2_'

# Inicializar string de análisis
analisis_resultado = ""
columnas_finales_lista = []

# Llamar a la función recursiva
analisis_resultado = Recursividad(reporte_ejemplo, tabla_ejemplo, columna_ejemplo, 1, set(), None, analisis_resultado, columnas_finales_lista)

# Concatenar las columnas finales directas de bajada al final del análisis
if columnas_finales_lista:
    analisis_resultado += "\nColumnas Base (Directas de bajada):\n" + ', '.join(set(columnas_finales_lista))

# Mostrar el resultado del análisis
print("Análisis Jerárquico de dependencias:")
print(analisis_resultado)
# Out:
# Análisis Jerárquico de dependencias:
#
# Columnas Base (Directas de bajada):
# HR Headcount[# Trámites 2_]

# %%
df_resultado.head()
# Out:
#                              reporte Tabla Nombre  \
# 0  Reporte de nutrición de Gonza 130    Porciones
# 1  Reporte de nutrición de Gonza 130    Porciones
# 2  Reporte de nutrición de Gonza 130    Porciones
# 3  Reporte de nutrición de Gonza 130    Porciones
# 4  Reporte de nutrición de Gonza 130    Minerales
#
#                                    Columna Nombre Expresión Referencias  \
# 0  RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      None          []
# 1                                        Alimento      None          []
# 2                                Unidad principal      None          []
# 3                      Equivalencia en gramos (g)      None          []
# 4  RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61      None          []
#
#   Referencias 2 Es Final
# 0                     Si
# 1                     Si
# 2                     Si
# 3                     Si
# 4                     Si

# %%
import time  # Importar el módulo para medir el tiempo

# Función que realiza el análisis y devuelve el string del análisis con las columnas finales concatenadas
def generar_analisis_completo(row):
    reporte = row['reporte']
    tabla = row['Tabla Nombre']
    columna = row['Columna Nombre']

    # Inicializar variables
    analisis_resultado = ""
    columnas_finales_lista = []

    # Llamar a la función recursiva
    analisis_resultado = Recursividad(reporte, tabla, columna, 1, set(), None, analisis_resultado, columnas_finales_lista)

    # Concatenar las columnas finales al final del análisis
    if columnas_finales_lista:
        analisis_resultado += "\nColumnas Base (Directas de bajada):\n" + ', '.join(set(columnas_finales_lista))

    return analisis_resultado

# Medir el tiempo de ejecución
start_time = time.time()  # Tiempo de inicio

# Aplicar la función a cada fila del DataFrame y agregar la nueva columna "Análisis Completo"
df_resultado['Análisis Completo'] = df_resultado.apply(
    lambda row: generar_analisis_completo(row), axis=1
)

end_time = time.time()  # Tiempo de finalización

# Calcular el tiempo de ejecución
execution_time = end_time - start_time

# Mostrar el DataFrame con la nueva columna "Análisis Completo"
print(df_resultado[['reporte', 'Tabla Nombre', 'Columna Nombre', 'Análisis Completo', 'Referencias 2']])

# Mostrar el tiempo de ejecución
print(f"Tiempo de ejecución: {execution_time:.2f} segundos")
# Out:
#                                reporte Tabla Nombre  \
# 0    Reporte de nutrición de Gonza 130    Porciones
# 1    Reporte de nutrición de Gonza 130    Porciones
# 2    Reporte de nutrición de Gonza 130    Porciones
# 3    Reporte de nutrición de Gonza 130    Porciones
# 4    Reporte de nutrición de Gonza 130    Minerales
# ..                                 ...          ...
# 271  Reporte de nutrición de Gonza 130     Consumos
# 272  Reporte de nutrición de Gonza 130     Consumos
# 273  Reporte de nutrición de Gonza 130     Consumos
# 274  Reporte de nutrición de Gonza 130    Alimentos
# 275  Reporte de nutrición de Gonza 130   Nutrientes
#
#                                      Columna Nombre  \
# 0    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# 1                                          Alimento
# 2                                  Unidad principal
# 3                        Equivalencia en gramos (g)
# 4    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# ..                                              ...
# 271                           Consumo Alil-sulfuros
# 272                          Target - Alil-sulfuros
# 273                % Últimos 7 Días - Alil-sulfuros
# 274                                          Medida
# 275                                  ColorParametro
#
#                                      Análisis Completo  \
# 0    \nColumnas Base (Directas de bajada):\nPorcion...
# 1    \nColumnas Base (Directas de bajada):\nPorcion...
# 2    \nColumnas Base (Directas de bajada):\nPorcion...
# 3    \nColumnas Base (Directas de bajada):\nPorcion...
# 4    \nColumnas Base (Directas de bajada):\nMineral...
# ..                                                 ...
# 271  Nivel 1:\nConsumos[Consumo Alil-sulfuros]=\nSU...
# 272  Nivel 1:\nConsumos[Target - Alil-sulfuros]=\n5...
# 273  Nivel 1:\nConsumos[% Últimos 7 Días - Alil-sul...
# 274  \nColumnas Base (Directas de bajada):\nAliment...
# 275  Nivel 1:\nNutrientes[ColorParametro]=\nLOOKUPV...
#
#                                          Referencias 2
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 271             Alimentos[Alimento],Consumos[Alimento]
# 272
# 273            Consumos[Timestamp],Consumos[Timestamp]
# 274
# 275  NutrientesColores[Color],NutrientesColores[Nom...
#
# [276 rows x 5 columns]
# Tiempo de ejecución: 0.96 segundos

# %%
import os
import pandas as pd


# Carpeta destino y nombre del archivo
carpeta_destino = config.step3_analisis_dependencias
os.makedirs(carpeta_destino, exist_ok=True)

nombre_archivo = f"{usuario} + {reporte} + analisis de dependencias.xlsx"
ruta_final = os.path.join(carpeta_destino, nombre_archivo)

# Crear archivo nuevo con hoja 'Dependency Analysis'
with pd.ExcelWriter(ruta_final, engine='openpyxl', mode='w') as writer:
    df_resultado.to_excel(writer, sheet_name="Dependency Analysis", index=False)

print(f"[CREADO] Archivo: {ruta_final}")
# Out:
# [CREADO] Archivo: C:\Users\Administrator\DMV Automation - 10 Jun\DMV Files\testUser + Reporte de nutrición de Gonza 130 + analisis de dependencias.xlsx

# %%
df_resultado
# Out:
#                                reporte Tabla Nombre  \
# 0    Reporte de nutrición de Gonza 130    Porciones
# 1    Reporte de nutrición de Gonza 130    Porciones
# 2    Reporte de nutrición de Gonza 130    Porciones
# 3    Reporte de nutrición de Gonza 130    Porciones
# 4    Reporte de nutrición de Gonza 130    Minerales
# ..                                 ...          ...
# 271  Reporte de nutrición de Gonza 130     Consumos
# 272  Reporte de nutrición de Gonza 130     Consumos
# 273  Reporte de nutrición de Gonza 130     Consumos
# 274  Reporte de nutrición de Gonza 130    Alimentos
# 275  Reporte de nutrición de Gonza 130   Nutrientes
#
#                                      Columna Nombre  \
# 0    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# 1                                          Alimento
# 2                                  Unidad principal
# 3                        Equivalencia en gramos (g)
# 4    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# ..                                              ...
# 271                           Consumo Alil-sulfuros
# 272                          Target - Alil-sulfuros
# 273                % Últimos 7 Días - Alil-sulfuros
# 274                                          Medida
# 275                                  ColorParametro
#
#                                              Expresión  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 271  SUMX(\n    Consumos,\n    \n    VAR valorPor10...
# 272                         50 // Ejemplo: 50 mg\n
# 273  VAR FechaMax = MAX(Consumos[Timestamp])\n    V...
# 274                                               None
# 275  LOOKUPVALUE(\n    NutrientesColores[Color],\n ...
#
#                                            Referencias  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 271            [Alimentos.Alimento, Consumos.Alimento]
# 272                                                 []
# 273           [Consumos.Timestamp, Consumos.Timestamp]
# 274                                                 []
# 275  [NutrientesColores.Color, NutrientesColores.No...
#
#                                          Referencias 2 Es Final  \
# 0                                                            Si
# 1                                                            Si
# 2                                                            Si
# 3                                                            Si
# 4                                                            Si
# ..                                                 ...      ...
# 271             Alimentos[Alimento],Consumos[Alimento]       No
# 272                                                          No
# 273            Consumos[Timestamp],Consumos[Timestamp]       No
# 274                                                          Si
# 275  NutrientesColores[Color],NutrientesColores[Nom...       No
#
#                                      Análisis Completo
# 0    \nColumnas Base (Directas de bajada):\nPorcion...
# 1    \nColumnas Base (Directas de bajada):\nPorcion...
# 2    \nColumnas Base (Directas de bajada):\nPorcion...
# 3    \nColumnas Base (Directas de bajada):\nPorcion...
# 4    \nColumnas Base (Directas de bajada):\nMineral...
# ..                                                 ...
# 271  Nivel 1:\nConsumos[Consumo Alil-sulfuros]=\nSU...
# 272  Nivel 1:\nConsumos[Target - Alil-sulfuros]=\n5...
# 273  Nivel 1:\nConsumos[% Últimos 7 Días - Alil-sul...
# 274  \nColumnas Base (Directas de bajada):\nAliment...
# 275  Nivel 1:\nNutrientes[ColorParametro]=\nLOOKUPV...
#
# [276 rows x 8 columns]
