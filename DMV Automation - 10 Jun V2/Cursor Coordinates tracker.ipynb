# %%
from pynput import mouse

def on_click(x, y, button, pressed):
    if pressed:
        print(f"🖱️ Click detectado en: X={x}, Y={y}")

# Inicia el listener de mouse
with mouse.Listener(on_click=on_click) as listener:
    print("🕵️ Esperando clics... (Ctrl+C para salir)")
    listener.join()
# Out:
# 🕵️ Esperando clics... (Ctrl+C para salir)
# 🖱️ Click detectado en: X=767, Y=608
# 🖱️ Click detectado en: X=372, Y=565
# 🖱️ Click detectado en: X=534, Y=356
# 🖱️ Click detectado en: X=878, Y=454
# 🖱️ Click detectado en: X=616, Y=757
# 🖱️ Click detectado en: X=573, Y=688
# 🖱️ Click detectado en: X=289, Y=448
# 🖱️ Click detectado en: X=653, Y=698
# 🖱️ Click detectado en: X=927, Y=593
# 🖱️ Click detectado en: X=910, Y=601
# 🖱️ Click detectado en: X=910, Y=601
# 🖱️ Click detectado en: X=911, Y=619
# 🖱️ Click detectado en: X=911, Y=619
# 🖱️ Click detectado en: X=977, Y=648
# 🖱️ Click detectado en: X=759, Y=757
# 🖱️ Click detectado en: X=741, Y=686
# 🖱️ Click detectado en: X=384, Y=440
# 🖱️ Click detectado en: X=337, Y=474
# 🖱️ Click detectado en: X=258, Y=454
# 🖱️ Click detectado en: X=258, Y=454
# 🖱️ Click detectado en: X=1575, Y=1205
# 🖱️ Click detectado en: X=1582, Y=1387
# 🖱️ Click detectado en: X=1582, Y=1387
# 🖱️ Click detectado en: X=1575, Y=1205
# ...

# %%
import sys
print(sys.executable)  # para ver qué Python usa el notebook
!"{sys.executable}" -m pip install pynput
# Out:
# C:\ProgramData\anaconda3\python.exe
# ...

# %%
from pywinauto import Desktop, mouse

pos = mouse.get_position()
ctrl = Desktop(backend="uia").from_point(pos)
print(f"Texto: {ctrl.window_text()} | Clase: {ctrl.element_info.class_name}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pywinauto import Desktop, mouse
# ----> 3 pos = mouse.get_position()
#       4 ctrl = Desktop(backend="uia").from_point(pos)
#       5 print(f"Texto: {ctrl.window_text()} | Clase: {ctrl.element_info.class_name}")
#
# AttributeError: module 'pywinauto.mouse' has no attribute 'get_position'

# %%
🕵️ Esperando clics... (Ctrl+C para salir)
🖱️ Click detectado en: X=607, Y=983
    🖱️ Click detectado en: X=718, Y=1014
