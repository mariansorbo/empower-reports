# %%
import config
import config_runtime
from datetime import datetime
# Configuración
path_carpeta = config.step1_extracciones_dmv 
usuario_objetivo = config_runtime.usuario
reporte_objetivo=config_runtime.reporte

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='openpyxl')

# %%
import os
import re
from collections import defaultdict

def detectar_reportes(path_carpeta, usuario):
    archivos = os.listdir(path_carpeta)
    patron = re.compile(rf"^{usuario} \+ (.+?) \+ ")
    reportes = defaultdict(list)

    for archivo in archivos:
        if archivo.endswith(".xlsx"):
            match = patron.match(archivo)
            if match:
                nombre_reporte = match.group(1).strip()
                reportes[nombre_reporte].append(archivo)

    return dict(reportes)

# %%
usuario = config_runtime.usuario

reportes = detectar_reportes(path_carpeta, usuario)
for nombre, archivos in reportes.items():
    print(f"\n📊 Reporte: {nombre}")
    for a in archivos:
        print("  -", a)
# Out:
# 📊 Reporte: Empower BI V3 - Copy - Copy - Copy
#   - testUser + Empower BI V3 - Copy - Copy - Copy + analisis de dependencias.xlsx
#
# 📊 Reporte: Empower BI V4
#   - testUser + Empower BI V4 + analisis de dependencias.xlsx
#   - testUser + Empower BI V4 + columnas.xlsx
#   - testUser + Empower BI V4 + metricas.xlsx
#   - testUser + Empower BI V4 + partitions.xlsx
#   - testUser + Empower BI V4 + relaciones.xlsx
#   - testUser + Empower BI V4 + tablas.xlsx
#
# 📊 Reporte: Plantilla Empower BI
#   - testUser + Plantilla Empower BI + analisis de dependencias.xlsx
#   - testUser + Plantilla Empower BI + columnas.xlsx
#   - testUser + Plantilla Empower BI + metricas.xlsx
#   - testUser + Plantilla Empower BI + partitions.xlsx
#   - testUser + Plantilla Empower BI + relaciones.xlsx
#   - testUser + Plantilla Empower BI + tablas.xlsx
#
# 📊 Reporte: Plantilla Empower BI V4
#   - testUser + Plantilla Empower BI V4 + columnas.xlsx
#   - testUser + Plantilla Empower BI V4 + metricas.xlsx
#   - testUser + Plantilla Empower BI V4 + partitions.xlsx
#   - testUser + Plantilla Empower BI V4 + relaciones.xlsx
#   - testUser + Plantilla Empower BI V4 + tablas.xlsx
#
# 📊 Reporte: Reporte Nutrición V9
#   - testUser + Reporte Nutrición V9 + analisis de dependencias.xlsx
#   - testUser + Reporte Nutrición V9 + columnas.xlsx
#   - testUser + Reporte Nutrición V9 + metricas.xlsx
#   - testUser + Reporte Nutrición V9 + partitions.xlsx
#   - testUser + Reporte Nutrición V9 + relaciones.xlsx
#   - testUser + Reporte Nutrición V9 + tablas.xlsx

# %%
import os
import pandas as pd
import re
from collections import defaultdict
import config
import config_runtime

# Configuración
path_carpeta = config.step1_extracciones_dmv
usuario_objetivo = config_runtime.usuario.strip().lower()

# Tipos válidos normalizados
tipos_validos = [
    "columnas",
    "metricas",
    "partitions",
    "tablas",
    "relaciones",
    "analisis de dependencias"
]

# Inicializar contenedor por tipo
dfs_por_tipo = defaultdict(list)

# Recorrer archivos
for archivo in os.listdir(path_carpeta):
    if not archivo.endswith(".xlsx"):
        continue

    match = re.match(r"(.*?)\s*\+\s*(.*?)\s*\+\s*(.*?)\.xlsx", archivo)
    if not match:
        continue

    usuario, reporte, tipo = match.groups()
    usuario_norm = usuario.strip().lower()
    tipo_norm = tipo.strip().lower()

    if usuario_norm != usuario_objetivo:
        continue

    if tipo_norm not in tipos_validos:
        continue

    try:
        filepath = os.path.join(path_carpeta, archivo)
        df = pd.read_excel(filepath)
        dfs_por_tipo[tipo_norm].append(df)
        print(f"[✓] Cargado archivo de tipo '{tipo_norm}': {archivo} ({df.shape[0]} filas)")
    except Exception as e:
        print(f"[!] Error leyendo '{archivo}': {e}")

# Combinar todos los archivos por tipo
dfs_finales = {}
for tipo, lista_dfs in dfs_por_tipo.items():
    if lista_dfs:
        df_total = pd.concat(lista_dfs, ignore_index=True)
        dfs_finales[tipo] = df_total
        print(f"[📊] Unificado df_{tipo}: {df_total.shape[0]} filas")

        # Guardar como variable global si querés
        globals()[f"df_{tipo.replace(' ', '_')}"] = df_total
# Out:
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Empower BI V3 - Copy - Copy - Copy + analisis de dependencias.xlsx (252 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Empower BI V4 + analisis de dependencias.xlsx (255 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Empower BI V4 + columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Empower BI V4 + metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Empower BI V4 + partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Empower BI V4 + relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Empower BI V4 + tablas.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Plantilla Empower BI + analisis de dependencias.xlsx (97 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Plantilla Empower BI + columnas.xlsx (145 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Plantilla Empower BI + metricas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Plantilla Empower BI + partitions.xlsx (10 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Plantilla Empower BI + relaciones.xlsx (9 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Plantilla Empower BI + tablas.xlsx (10 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Plantilla Empower BI V4 + columnas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Plantilla Empower BI V4 + metricas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Plantilla Empower BI V4 + partitions.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Plantilla Empower BI V4 + relaciones.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Plantilla Empower BI V4 + tablas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Reporte Nutrición V9 + analisis de dependencias.xlsx (275 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Reporte Nutrición V9 + columnas.xlsx (162 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Reporte Nutrición V9 + metricas.xlsx (118 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Reporte Nutrición V9 + partitions.xlsx (19 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Reporte Nutrición V9 + relaciones.xlsx (15 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Reporte Nutrición V9 + tablas.xlsx (19 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser+Empower BI V3 - Copy - Copy - Copy+columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser+Empower BI V3 - Copy - Copy - Copy+metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser+Empower BI V3 - Copy - Copy - Copy+partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser+Empower BI V3 - Copy - Copy - Copy+relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser+Empower BI V3 - Copy - Copy - Copy+tablas.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser+Empower BI V3+columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser+Empower BI V3+metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser+Empower BI V3+partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser+Empower BI V3+relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser+Empower BI V3+tablas.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser+Reporte de nutrición de Gonza 130+columnas.xlsx (163 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser+Reporte de nutrición de Gonza 130+metricas.xlsx (118 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser+Reporte de nutrición de Gonza 130+partitions.xlsx (19 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser+Reporte de nutrición de Gonza 130+relaciones.xlsx (15 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser+Reporte de nutrición de Gonza 130+tablas.xlsx (19 filas)
# [📊] Unificado df_analisis de dependencias: 879 filas
# [📊] Unificado df_columnas: 1415 filas
# [📊] Unificado df_metricas: 257 filas
# [📊] Unificado df_partitions: 111 filas
# [📊] Unificado df_relaciones: 78 filas
# [📊] Unificado df_tablas: 111 filas
# C:\Users\Mariano\AppData\Local\Temp\2\ipykernel_5616\4067550946.py:56: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_total = pd.concat(lista_dfs, ignore_index=True)

# %%
import import_ipynb
import Funciones  # without .ipynb

#llamo a la funcion para unificar columnas y metricas
df_unificado = Funciones.estandarizar_y_unir(df_columnas, df_metricas)  # call your function

#guardo el nuevo archivo "Columnas y MEtricas.xlsx"
df_unificado.head()
# Out:
#          Reporte   ID TableID                                            Name  \
# 0  Empower BI V4   11      10  RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# 1  Empower BI V4  140      10                                            Tipo
# 2  Empower BI V4  141      10                                         Reporte
# 3  Empower BI V4  142      10                                              ID
# 4  Empower BI V4  143      10                                         TableID
#
#   IsHidden DataType                                         Expression  \
# 0     True        3                                                NaN
# 1     True        2  if(Columnas[Expression]=BLANK(),"Columna","Col...
# 2    False        1                                                NaN
# 3    False        1                                                NaN
# 4    False        1                                                NaN
#
#    ModifiedTime  StructureModifiedTime DisplayFolder    Origen
# 0  45634.637941           45634.637941           NaN  Columnas
# 1  45634.658564           45634.637941           NaN  Columnas
# 2  45634.637941           45634.637941           NaN  Columnas
# 3  45634.637941           45634.637941           NaN  Columnas
# 4  45634.637941           45634.637941           NaN  Columnas

# %%
df_tablas["Reporte + TableID"] = df_tablas["Reporte"] + " - " + df_tablas["ID"].astype(str)
df_tablas.head()
df_partitions["Reporte + TableID"] = df_partitions["Reporte"] + " - " + df_partitions["TableID"].astype(str)
df_partitions.head()
df_relaciones["Reporte + From TableID"]=df_relaciones["Reporte"]+ " - " +df_relaciones["FromTableID"].astype(str)
df_relaciones["Reporte + To TableID"]=df_relaciones["Reporte"]+ " - " +df_relaciones["ToTableID"].astype(str)
df_relaciones.head()
df_unificado["Reporte + TableID"] = df_unificado["Reporte"] + " - " + df_unificado["TableID"].astype(str)
df_unificado.head()


df_unificado
# Out:
#                                 Reporte   ID TableID  \
# 0                         Empower BI V4   11      10
# 1                         Empower BI V4  140      10
# 2                         Empower BI V4  141      10
# 3                         Empower BI V4  142      10
# 4                         Empower BI V4  143      10
# ...                                 ...  ...     ...
# 1667  Reporte de nutrición de Gonza 130  359      19
# 1668  Reporte de nutrición de Gonza 130  360      19
# 1669  Reporte de nutrición de Gonza 130  361      19
# 1670  Reporte de nutrición de Gonza 130  362      22
# 1671  Reporte de nutrición de Gonza 130  363      49
#
#                                                 Name IsHidden DataType  \
# 0     RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61     True        3
# 1                                               Tipo     True        2
# 2                                            Reporte    False        1
# 3                                                 ID    False        1
# 4                                            TableID    False        1
# ...                                              ...      ...      ...
# 1667                           Consumo Alil-sulfuros    False        8
# 1668                          Target - Alil-sulfuros    False        6
# 1669                % Últimos 7 Días - Alil-sulfuros    False        8
# 1670                                          Medida    False        6
# 1671                                  ColorParametro    False        2
#
#                                              Expression  ModifiedTime  \
# 0                                                   NaN  45634.637941
# 1     if(Columnas[Expression]=BLANK(),"Columna","Col...  45634.658564
# 2                                                   NaN  45634.637941
# 3                                                   NaN  45634.637941
# 4                                                   NaN  45634.637941
# ...                                                 ...           ...
# 1667  SUMX(\n    Consumos,\n    \n    VAR valorPor10...  45877.073091
# 1668                         50 // Ejemplo: 50 mg\n      45877.073091
# 1669  VAR FechaMax = MAX(Consumos[Timestamp])\n    V...  45877.073091
# 1670                                                NaN  45877.073091
# 1671  LOOKUPVALUE(\n    NutrientesColores[Color],\n ...  45877.073091
#
#       StructureModifiedTime                  DisplayFolder    Origen  \
# 0              45634.637941                            NaN  Columnas
# 1              45634.637941                            NaN  Columnas
# 2              45634.637941                            NaN  Columnas
# 3              45634.637941                            NaN  Columnas
# 4              45634.637941                            NaN  Columnas
# ...                     ...                            ...       ...
# 1667           45877.073076        Consumo - Antioxidantes  Métricas
# 1668           45877.073076  Target Diario - Antioxidantes  Métricas
# 1669           45877.073076                            NaN  Métricas
# 1670           45877.073076                            NaN  Métricas
# 1671           45877.073076                            NaN  Métricas
#
#                            Reporte + TableID
# 0                         Empower BI V4 - 10
# 1                         Empower BI V4 - 10
# 2                         Empower BI V4 - 10
# 3                         Empower BI V4 - 10
# 4                         Empower BI V4 - 10
# ...                                      ...
# 1667  Reporte de nutrición de Gonza 130 - 19
# 1668  Reporte de nutrición de Gonza 130 - 19
# 1669  Reporte de nutrición de Gonza 130 - 19
# 1670  Reporte de nutrición de Gonza 130 - 22
# 1671  Reporte de nutrición de Gonza 130 - 49
#
# [1672 rows x 12 columns]

# %% [markdown]
# '''5. 📊 Consolidación de los datos en un solo Excel
# Todos los DataFrames (columnas, métricas, tablas, relaciones y particiones) son escritos en un único archivo Excel con múltiples hojas (sheet_name).
#
# Este archivo se guarda en:
#
# 📁 OneDrive:
# C:\Users\Administrator\OneDrive\Empower BI Archivos\Mariano + Reporte + (fecha).xlsx

# %%
#Configuración
# Ruta de carpeta y nombre de archivo
carpeta_destino = config.step2_archivos_consolidados
fecha = datetime.now().strftime("%Y-%m-%d")
nombre_archivo = f"{usuario} - Consolidado.xlsx"

# %%
#ONE DRIVE

import pandas as pd
import os
from datetime import datetime


ruta_final = os.path.join(carpeta_destino, nombre_archivo)

# Lista de tus DataFrames
dfs = {
    "Columnas y Métricas": df_unificado,
    "Partitions": df_partitions,
    "Tablas": df_tablas,
    "Relaciones": df_relaciones,
    "Analisis de Dependencias":df_analisis_de_dependencias
}

# Guardar como Excel con múltiples hojas
with pd.ExcelWriter(ruta_final, engine='xlsxwriter') as writer:
    for nombre_hoja, df in dfs.items():
        df.to_excel(writer, sheet_name=nombre_hoja[:31], index=False)  # 31 = máx. de caracteres en nombre de hoja

print(f"[✓] Archivo Excel guardado exitosamente en: {ruta_final}")
# Out:
# [✓] Archivo Excel guardado exitosamente en: C:\Users\Mariano\Documents\DMV Automation - 10 Jun\Archivos Consolidados\testUser - Consolidado.xlsx

# %%
df_analisis_de_dependencias
# Out:
#                                 reporte Tabla Nombre  \
# 0    Empower BI V3 - Copy - Copy - Copy     Columnas
# 1    Empower BI V3 - Copy - Copy - Copy     Columnas
# 2    Empower BI V3 - Copy - Copy - Copy     Columnas
# 3    Empower BI V3 - Copy - Copy - Copy     Columnas
# 4    Empower BI V3 - Copy - Copy - Copy     Columnas
# ..                                  ...          ...
# 874                Reporte Nutrición V9     Consumos
# 875                Reporte Nutrición V9     Consumos
# 876                Reporte Nutrición V9     Consumos
# 877                Reporte Nutrición V9    Alimentos
# 878                Reporte Nutrición V9   Nutrientes
#
#                                      Columna Nombre  \
# 0    RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# 1                                              Tipo
# 2                                           Reporte
# 3                                                ID
# 4                                           TableID
# ..                                              ...
# 874                           Consumo Alil-sulfuros
# 875                          Target - Alil-sulfuros
# 876                % Últimos 7 Días - Alil-sulfuros
# 877                                          Medida
# 878                                  ColorParametro
#
#                                              Expresión  \
# 0                                                  NaN
# 1    if(Columnas[Expression]=BLANK(),"Columna","Col...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 874  SUMX(\n    Consumos,\n    \n    VAR valorPor10...
# 875                         50 // Ejemplo: 50 mg\n
# 876  VAR FechaMax = MAX(Consumos[Timestamp])\n    V...
# 877                                                NaN
# 878  LOOKUPVALUE(\n    NutrientesColores[Color],\n ...
#
#                                            Referencias  \
# 0                                                   []
# 1                              ['Columnas.Expression']
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 874        ['Alimentos.Alimento', 'Consumos.Alimento']
# 875                                                 []
# 876       ['Consumos.Timestamp', 'Consumos.Timestamp']
# 877                                                 []
# 878  ['NutrientesColores.Color', 'NutrientesColores...
#
#                                          Referencias 2 Es Final  \
# 0                                                  NaN       Si
# 1                                 Columnas[Expression]       No
# 2                                                  NaN       Si
# 3                                                  NaN       Si
# 4                                                  NaN       Si
# ..                                                 ...      ...
# 874             Alimentos[Alimento],Consumos[Alimento]       No
# 875                                                NaN       No
# 876            Consumos[Timestamp],Consumos[Timestamp]       No
# 877                                                NaN       Si
# 878  NutrientesColores[Color],NutrientesColores[Nom...       No
#
#                                      Análisis Completo
# 0    \nColumnas Base (Directas de bajada):\nColumna...
# 1    Nivel 1:\nColumnas[Tipo]=\nif(Columnas[Express...
# 2    \nColumnas Base (Directas de bajada):\nColumna...
# 3    \nColumnas Base (Directas de bajada):\nColumna...
# 4    \nColumnas Base (Directas de bajada):\nColumna...
# ..                                                 ...
# 874  Nivel 1:\nConsumos[Consumo Alil-sulfuros]=\nSU...
# 875  Nivel 1:\nConsumos[Target - Alil-sulfuros]=\n5...
# 876  Nivel 1:\nConsumos[% Últimos 7 Días - Alil-sul...
# 877  \nColumnas Base (Directas de bajada):\nAliment...
# 878  Nivel 1:\nNutrientes[ColorParametro]=\nLOOKUPV...
#
# [879 rows x 8 columns]
