# %%
import subprocess
import sys
import os

# Reconfiguramos stdout del wrapper
if hasattr(sys.stdout, "reconfigure"):
    sys.stdout.reconfigure(encoding="utf-8", errors="replace")

def safe_print(text):
    try:
        print(text)
    except UnicodeEncodeError:
        enc = sys.stdout.encoding or "utf-8"
        fixed = text.encode(enc, errors="replace").decode(enc)
        print(fixed)

def ejecutar_script(ruta_script):
    try:
        safe_print(f"🚀 Ejecutando: {ruta_script}")
        # Creamos un entorno que fuerza UTF-8 en el hijo
        env = os.environ.copy()
        env["PYTHONIOENCODING"] = "utf-8"
        cmd = ["python", "-X", "utf8", ruta_script]

        result = subprocess.run(
            cmd,
            capture_output=True,
            text=True,
            encoding="utf-8",
            errors="replace",
            env=env
        )

        if result.returncode == 0:
            safe_print("✅ Script ejecutado correctamente.")
        else:
            safe_print(f"⚠️ Script ejecutado con errores (exit code {result.returncode})")

        safe_print("🔹 STDOUT:")
        safe_print(result.stdout)
        safe_print("🔸 STDERR:")
        safe_print(result.stderr)

    except Exception as e:
        safe_print("❌ Excepción inesperada al ejecutar el script:")
        safe_print(str(e))

# %%
import time
import config
import os
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
import subprocess

# Ruta a observar
watch_folder = config.base_report_directory

# Handler personalizado
class PbitHandler(FileSystemEventHandler):
    def on_created(self, event):
        if event.is_directory or not event.src_path.endswith(".pbit"):
            return
        
        print(f"🟢 Nuevo archivo .pbit detectado: {event.src_path}")
        time.sleep(5)  # esperar que termine de copiarse

        # Obtener nombre y separar por '+'
        filename = os.path.basename(event.src_path)
        filename_no_ext = os.path.splitext(filename)[0]

        if '+' in filename_no_ext:
            usuario, reporte = [x.strip() for x in filename_no_ext.split('+', 1)]
            print(f"👤 Usuario: {usuario}")
            print(f"📊 Reporte: {reporte}")
        else:
            print("⚠️ El nombre del archivo no contiene '+'. Debe seguir el formato usuario+reporte.pbit")
            return

        # Guardar en config_runtime.py
        try:
            with open("config_runtime.py", "w", encoding="utf-8") as f:
                f.write(f'usuario = "{usuario}"\n')
                f.write(f'reporte = "{reporte}"\n')
            print("📝 Datos guardados en config_runtime.py")
        except Exception as e:
            print(f"❌ Error al guardar config_runtime.py: {e}")
            return

        # Ejecutar script externo
        try:
            subprocess.run(["python", "procesador_pbit.py", event.src_path, usuario, reporte])
            print("✅ Archivo procesado con procesador_pbit.py")
        except Exception as e:
            print(f"❌ Error al procesar el archivo: {e}")

# Iniciar observador
if __name__ == "__main__":
    observer = Observer()
    handler = PbitHandler()
    observer.schedule(handler, path=watch_folder, recursive=False)
    observer.start()
    print(f"👂 Escuchando nuevos archivos .pbit en: {watch_folder}")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

    # Leer lo último escrito en config_runtime.py
    if os.path.exists("config_runtime.py"):
        config_vars = {}
        with open("config_runtime.py", "r", encoding="utf-8") as f:
            exec(f.read(), config_vars)
        print(f"\n🔁 Últimos valores guardados:")
        print(f"👤 Usuario: {config_vars['usuario']}")
        print(f"📊 Reporte: {config_vars['reporte']}")

time.sleep(2)

# %%
ejecutar_script(r"C:\Users\Administrator\DMV Automation\One_Extraccion_DMVs_V3.py")
# Out:
# 🚀 Ejecutando: C:\Users\Administrator\DMV Automation\One_Extraccion_DMVs_V3.py
# ✅ Script ejecutado correctamente.
# 🔹 STDOUT:
# Analizando el reporte : Empower BI V3 - Copy - Copy - Copy | Usuario: testUser
# 📊 Analizando el reporte real: testUser + Empower BI V3 - Copy - Copy - Copy.pbit  | Usuario: testUser
# 🟡 Lanzando Power BI...
# 🟢 Power BI lanzado.
# 🔍 Buscando ventana principal de Power BI para maximizar...
# 🟢 Power BI maximizado correctamente.
# [✓] DAX Studio lanzado, esperando ventana...
# [✓] Ventana detectada: 'DAX Studio - 3.3.0'
# [✓] Ventana encontrada en índice 0: 'DaxStudio.UI.ViewModels.AutoSaveRecoveryDialogViewModel'
# [✓] Conectado a ventana de recuperación: 'DaxStudio.UI.ViewModels.AutoSaveRecoveryDialogViewModel'
# 🔍 Controles en la ventana de recuperación:
# [0] Image | '' | Image
# [1] Text | 'DAX Studio was not shutdown cleanly the last time it was run' | Text
# [2] Text | 'DAX Studio was not shutdown cleanly the last time it was run' | TextBlock
# [3] Text | 'The following documents had unsaved changes:' | Text
# [4] Text | 'The following documents had unsaved changes:' | TextBlock
# [5] CheckBox | 'Select All' | CheckBox
# [6] Text | 'Select All' | TextBlock
# [7] List | '' | ListView
# [8] ListItem | 'DaxStudio.UI.Model.AutoSaveIndexEntry' | ListBoxItem
# [9] CheckBox | '' | CheckBox
# [10] Image | '' | Image
# [11] Text | '' | TextBlock
# [12] Text | 'Query1.dax' | TextBlock
# [13] Text | '<Unsaved File>' | TextBlock
# [14] Button | 'Open' | Button
# [15] Text | '_Open' | TextBlock
# [16] Button | 'Cancel' | Button
# [17] Text | 'Cancel' | TextBlock
# 🛑 Botón 'Cancel' presionado con éxito.
# [✓] Ventana principal detectada: 'DAX Studio - 3.3.0'
# [...] Buscando ventana de conexión dentro de DAX Studio...
# [✓] Radio button seleccionado: 'Power BI / SSDT Model'
# [✓] Click en botón 'Connect' exitoso.
#
# 🔁 Ejecutando query: columnas
# [✓] Query ejecutado.
# [📁] Esperando ventana 'Save As'...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo: testUser+Empower BI V3 - Copy - Copy - Copy+columnas.xlsx
# [✓] Carpeta destino: C:\Users\Administrator\DMV Automation\DMV Files
# [✓] Click en 'Save' exitoso.
# [✅] Archivo 'testUser+Empower BI V3 - Copy - Copy - Copy+columnas.xlsx' guardado correctamente.
#
# 🔁 Ejecutando query: metricas
# [✓] Query ejecutado.
# [📁] Esperando ventana 'Save As'...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo: testUser+Empower BI V3 - Copy - Copy - Copy+metricas.xlsx
# [✓] Carpeta destino: C:\Users\Administrator\DMV Automation\DMV Files
# [✓] Click en 'Save' exitoso.
# [✅] Archivo 'testUser+Empower BI V3 - Copy - Copy - Copy+metricas.xlsx' guardado correctamente.
#
# 🔁 Ejecutando query: tablas
# [✓] Query ejecutado.
# [📁] Esperando ventana 'Save As'...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo: testUser+Empower BI V3 - Copy - Copy - Copy+tablas.xlsx
# [✓] Carpeta destino: C:\Users\Administrator\DMV Automation\DMV Files
# [✓] Click en 'Save' exitoso.
# [✅] Archivo 'testUser+Empower BI V3 - Copy - Copy - Copy+tablas.xlsx' guardado correctamente.
#
# 🔁 Ejecutando query: partitions
# [✓] Query ejecutado.
# [📁] Esperando ventana 'Save As'...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo: testUser+Empower BI V3 - Copy - Copy - Copy+partitions.xlsx
# [✓] Carpeta destino: C:\Users\Administrator\DMV Automation\DMV Files
# [✓] Click en 'Save' exitoso.
# [✅] Archivo 'testUser+Empower BI V3 - Copy - Copy - Copy+partitions.xlsx' guardado correctamente.
#
# 🔁 Ejecutando query: relaciones
# [✓] Query ejecutado.
# [📁] Esperando ventana 'Save As'...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo: testUser+Empower BI V3 - Copy - Copy - Copy+relaciones.xlsx
# [✓] Carpeta destino: C:\Users\Administrator\DMV Automation\DMV Files
# [✓] Click en 'Save' exitoso.
# [✅] Archivo 'testUser+Empower BI V3 - Copy - Copy - Copy+relaciones.xlsx' guardado correctamente.
# [✓] Power BI cerrado correctamente.
# [↪] Click en 'Don't Save'
# [↪] Click en 'Cancel' de recuperación
# [↪] Click en 'Cancel' de recuperación
#
# 🔸 STDERR:

# %%
ejecutar_script(r"C:\Users\Administrator\DMV Automation\Two_A_Analisis_Dependencias.py")
# Out:
# 🚀 Ejecutando: C:\Users\Administrator\DMV Automation\Two_A_Analisis_Dependencias.py
# ✅ Script ejecutado correctamente.
# 🔹 STDOUT:
# [OK] Cargado archivo de columnas: testUser+Empower BI V3 - Copy - Copy - Copy+columnas.xlsx
# [OK] Cargado archivo de métricas: testUser+Empower BI V3 - Copy - Copy - Copy+metricas.xlsx
# [OK] Cargado archivo de tablas: testUser+Empower BI V3 - Copy - Copy - Copy+tablas.xlsx
# Empower BI V3 - Copy - Copy - Copy Columnas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Columnas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Columnas Tipo Columnas|Tipo
# Empower BI V3 - Copy - Copy - Copy Columnas Reporte Columnas|Reporte
# Empower BI V3 - Copy - Copy - Copy Columnas ID Columnas|ID
# Empower BI V3 - Copy - Copy - Copy Columnas TableID Columnas|TableID
# Empower BI V3 - Copy - Copy - Copy Columnas ExplicitName Columnas|ExplicitName
# Empower BI V3 - Copy - Copy - Copy Columnas IsHidden Columnas|IsHidden
# Empower BI V3 - Copy - Copy - Copy Columnas ColumnStorageID Columnas|ColumnStorageID
# Empower BI V3 - Copy - Copy - Copy Columnas Type Columnas|Type
# Empower BI V3 - Copy - Copy - Copy Columnas SourceColumn Columnas|SourceColumn
# Empower BI V3 - Copy - Copy - Copy Columnas Expression Columnas|Expression
# Empower BI V3 - Copy - Copy - Copy Columnas ModifiedTime Columnas|ModifiedTime
# Empower BI V3 - Copy - Copy - Copy Columnas StructureModifiedTime Columnas|StructureModifiedTime
# Empower BI V3 - Copy - Copy - Copy Columnas DisplayFolder Columnas|DisplayFolder
# Empower BI V3 - Copy - Copy - Copy Columnas Reporte + TableID Columnas|Reporte + TableID
# Empower BI V3 - Copy - Copy - Copy Tablas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Tablas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Tablas Automatic DateTable Flag Tablas|Automatic DateTable Flag
# Empower BI V3 - Copy - Copy - Copy Tablas Report Tablas|Report
# Empower BI V3 - Copy - Copy - Copy Tablas ID Tablas|ID
# Empower BI V3 - Copy - Copy - Copy Tablas Name Tablas|Name
# Empower BI V3 - Copy - Copy - Copy Tablas IsHidden Tablas|IsHidden
# Empower BI V3 - Copy - Copy - Copy Tablas TableStorageID Tablas|TableStorageID
# Empower BI V3 - Copy - Copy - Copy Tablas ModifiedTime Tablas|ModifiedTime
# Empower BI V3 - Copy - Copy - Copy Tablas StructureModifiedTime Tablas|StructureModifiedTime
# Empower BI V3 - Copy - Copy - Copy Tablas Reporte + Tabla Tablas|Reporte + Tabla
# Empower BI V3 - Copy - Copy - Copy Tablas Reporte + TableID Tablas|Reporte + TableID
# Empower BI V3 - Copy - Copy - Copy Tablas # Row Count 1 Tablas|# Row Count 1
# Empower BI V3 - Copy - Copy - Copy Tablas Automatic Date Table Tablas|Automatic Date Table
# Empower BI V3 - Copy - Copy - Copy Metricas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Metricas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Metricas Tipo Metricas|Tipo
# Empower BI V3 - Copy - Copy - Copy Metricas Reporte Metricas|Reporte
# Empower BI V3 - Copy - Copy - Copy Metricas ID Metricas|ID
# Empower BI V3 - Copy - Copy - Copy Metricas TableID Metricas|TableID
# Empower BI V3 - Copy - Copy - Copy Metricas Name Metricas|Name
# Empower BI V3 - Copy - Copy - Copy Metricas DataType Metricas|DataType
# Empower BI V3 - Copy - Copy - Copy Metricas Expression Metricas|Expression
# Empower BI V3 - Copy - Copy - Copy Metricas IsHidden Metricas|IsHidden
# Empower BI V3 - Copy - Copy - Copy Metricas ModifiedTime Metricas|ModifiedTime
# Empower BI V3 - Copy - Copy - Copy Metricas StructureModifiedTime Metricas|StructureModifiedTime
# Empower BI V3 - Copy - Copy - Copy Metricas DisplayFolder Metricas|DisplayFolder
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Columnas Y Metricas|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas nan Columnas Y Metricas|nan
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Supercampo 2 Columnas Y Metricas|Supercampo 2
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Report Columnas Y Metricas|Report
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Reporte + TableID Columnas Y Metricas|Reporte + TableID
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Nombre OK Columnas Y Metricas|Nombre OK
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas ANALISIS_DE_DEPENDENCIAS_ID Columnas Y Metricas|ANALISIS_DE_DEPENDENCIAS_ID
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 6 - From Tables|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables FROM Column 6 - From Tables|FROM Column
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Tables nan 6 - From Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 6 - To Tables|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Tables nan 6 - To Tables|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 6 - From Columns|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns FROM Table 6 - From Columns|FROM Table
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - From Columns nan 6 - From Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 6 - To Columns|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns TO Table 6 - To Columns|TO Table
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy 6 - To Columns nan 6 - To Columns|nan
# Empower BI V3 - Copy - Copy - Copy Partitions RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Partitions|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Partitions ID Partitions|ID
# Empower BI V3 - Copy - Copy - Copy Partitions TableID Partitions|TableID
# Empower BI V3 - Copy - Copy - Copy Partitions Name Partitions|Name
# Empower BI V3 - Copy - Copy - Copy Partitions Description Partitions|Description
# Empower BI V3 - Copy - Copy - Copy Partitions DataSourceID Partitions|DataSourceID
# Empower BI V3 - Copy - Copy - Copy Partitions QueryDefinition Partitions|QueryDefinition
# Empower BI V3 - Copy - Copy - Copy Partitions State Partitions|State
# Empower BI V3 - Copy - Copy - Copy Partitions Type Partitions|Type
# Empower BI V3 - Copy - Copy - Copy Partitions PartitionStorageID Partitions|PartitionStorageID
# Empower BI V3 - Copy - Copy - Copy Partitions Mode Partitions|Mode
# Empower BI V3 - Copy - Copy - Copy Partitions DataView Partitions|DataView
# Empower BI V3 - Copy - Copy - Copy Partitions ModifiedTime Partitions|ModifiedTime
# Empower BI V3 - Copy - Copy - Copy Partitions RefreshedTime Partitions|RefreshedTime
# Empower BI V3 - Copy - Copy - Copy Partitions SystemFlags Partitions|SystemFlags
# Empower BI V3 - Copy - Copy - Copy Partitions ErrorMessage Partitions|ErrorMessage
# Empower BI V3 - Copy - Copy - Copy Partitions RetainDataTillForceCalculate Partitions|RetainDataTillForceCalculate
# Empower BI V3 - Copy - Copy - Copy Partitions RangeStart Partitions|RangeStart
# Empower BI V3 - Copy - Copy - Copy Partitions RangeEnd Partitions|RangeEnd
# Empower BI V3 - Copy - Copy - Copy Partitions RangeGranularity Partitions|RangeGranularity
# Empower BI V3 - Copy - Copy - Copy Partitions RefreshBookmark Partitions|RefreshBookmark
# Empower BI V3 - Copy - Copy - Copy Partitions QueryGroupID Partitions|QueryGroupID
# Empower BI V3 - Copy - Copy - Copy Partitions ExpressionSourceID Partitions|ExpressionSourceID
# Empower BI V3 - Copy - Copy - Copy Partitions MAttributes Partitions|MAttributes
# Empower BI V3 - Copy - Copy - Copy Partitions Query Definition 2 Partitions|Query Definition 2
# Empower BI V3 - Copy - Copy - Copy Partitions EXCEED_LIMIT_FLAG Partitions|EXCEED_LIMIT_FLAG
# Empower BI V3 - Copy - Copy - Copy Partitions Length Partitions|Length
# Empower BI V3 - Copy - Copy - Copy Partitions Source Type Partitions|Source Type
# Empower BI V3 - Copy - Copy - Copy Partitions Reporte Partitions|Reporte
# Empower BI V3 - Copy - Copy - Copy Partitions Reporte + TableID Partitions|Reporte + TableID
# Empower BI V3 - Copy - Copy - Copy Partitions SourceType Partitions|SourceType
# Empower BI V3 - Copy - Copy - Copy Partitions RESULTADOS_EXADATA_ID Partitions|RESULTADOS_EXADATA_ID
# Empower BI V3 - Copy - Copy - Copy Partitions # Count (simple) Partitions|# Count (simple)
# Empower BI V3 - Copy - Copy - Copy Partitions Extracted Power Query Steps Partitions|Extracted Power Query Steps
# Empower BI V3 - Copy - Copy - Copy Partitions # Steps Partitions|# Steps
# Empower BI V3 - Copy - Copy - Copy Partitions Query Definition 3 Partitions|Query Definition 3
# Empower BI V3 - Copy - Copy - Copy Partitions Steps Partitions|Steps
# Empower BI V3 - Copy - Copy - Copy Partitions # Distinct Steps Partitions|# Distinct Steps
# Empower BI V3 - Copy - Copy - Copy Partitions Distinct Steps2 Partitions|Distinct Steps2
# Empower BI V3 - Copy - Copy - Copy Partitions # Steps modified Partitions|# Steps modified
# Empower BI V3 - Copy - Copy - Copy Partitions QUERy definition 4 Partitions|QUERy definition 4
# Empower BI V3 - Copy - Copy - Copy Relationships RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Relationships|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Relationships ID Relationships|ID
# Empower BI V3 - Copy - Copy - Copy Relationships FromTableID Relationships|FromTableID
# Empower BI V3 - Copy - Copy - Copy Relationships FromColumnID Relationships|FromColumnID
# Empower BI V3 - Copy - Copy - Copy Relationships FromCardinality Relationships|FromCardinality
# Empower BI V3 - Copy - Copy - Copy Relationships ToTableID Relationships|ToTableID
# Empower BI V3 - Copy - Copy - Copy Relationships ToColumnID Relationships|ToColumnID
# Empower BI V3 - Copy - Copy - Copy Relationships ToCardinality Relationships|ToCardinality
# Empower BI V3 - Copy - Copy - Copy Relationships ModifiedTime Relationships|ModifiedTime
# Empower BI V3 - Copy - Copy - Copy Relationships FROM Table Name Relationships|FROM Table Name
# Empower BI V3 - Copy - Copy - Copy Relationships TO Table Name Relationships|TO Table Name
# Empower BI V3 - Copy - Copy - Copy Relationships FROM Column Relationships|FROM Column
# Empower BI V3 - Copy - Copy - Copy Relationships TO Column Relationships|TO Column
# Empower BI V3 - Copy - Copy - Copy Relationships FROM Column Expression Relationships|FROM Column Expression
# Empower BI V3 - Copy - Copy - Copy Relationships TO Column Expression Relationships|TO Column Expression
# Empower BI V3 - Copy - Copy - Copy Relationships Tables Concat Relationships|Tables Concat
# Empower BI V3 - Copy - Copy - Copy Relationships Reporte Relationships|Reporte
# Empower BI V3 - Copy - Copy - Copy Relationships Reporte + From TableID Relationships|Reporte + From TableID
# Empower BI V3 - Copy - Copy - Copy Relationships Reporte + To TableID Relationships|Reporte + To TableID
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes Table ID 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|Table ID
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes Table Name 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|Table Name
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes Objetos Origen Exadata 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|Objetos Origen Exadata
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes Table Name Without Hash 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|Table Name Without Hash
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes RESULTADOS_EXADATA_ID 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|RESULTADOS_EXADATA_ID
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes Reporte 2 - Analisis de Dependencias de Tablas a EXADATA 2 - Reportes|Reporte
# Empower BI V3 - Copy - Copy - Copy Distinct Reportes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Distinct Reportes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Distinct Reportes nan Distinct Reportes|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Relationships (copy)|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) nan Relationships (copy)|nan
# Empower BI V3 - Copy - Copy - Copy Relationships (copy) Automatic Date Table Relationships (copy)|Automatic Date Table
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 2 - Análisis de Dependencias Intercolumnares - Reportes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes reporte 2 - Análisis de Dependencias Intercolumnares - Reportes|reporte
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Tabla Nombre 2 - Análisis de Dependencias Intercolumnares - Reportes|Tabla Nombre
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Columna Nombre 2 - Análisis de Dependencias Intercolumnares - Reportes|Columna Nombre
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Expresión 2 - Análisis de Dependencias Intercolumnares - Reportes|Expresión
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Referencias 2 - Análisis de Dependencias Intercolumnares - Reportes|Referencias
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Referencias 2 2 - Análisis de Dependencias Intercolumnares - Reportes|Referencias 2
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Es Final 2 - Análisis de Dependencias Intercolumnares - Reportes|Es Final
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Análisis Completo 2 - Análisis de Dependencias Intercolumnares - Reportes|Análisis Completo
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes ANALISIS_DE_DEPENDENCIAS_ID 2 - Análisis de Dependencias Intercolumnares - Reportes|ANALISIS_DE_DEPENDENCIAS_ID
# Empower BI V3 - Copy - Copy - Copy 2 - Análisis de Dependencias Intercolumnares - Reportes Renamed_String 2 - Análisis de Dependencias Intercolumnares - Reportes|Renamed_String
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Reporte 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Reporte
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Table ID 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Table ID
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Table Name 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Table Name
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Query 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Query
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Objetos Origen Exadata 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Objetos Origen Exadata
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Objetos Origen Exadata * 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Objetos Origen Exadata *
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes RESULTADOS_EXADATA_ID 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|RESULTADOS_EXADATA_ID
# Empower BI V3 - Copy - Copy - Copy 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes Table Name Without Hash 2 - Analisis de Dependencias de Tablas a EXADATA - Reportes|Table Name Without Hash
# Empower BI V3 - Copy - Copy - Copy Reports RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Reports|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Reports SERVER Reports|SERVER
# Empower BI V3 - Copy - Copy - Copy Reports ItemID Reports|ItemID
# Empower BI V3 - Copy - Copy - Copy Reports Path Reports|Path
# Empower BI V3 - Copy - Copy - Copy Reports Name Reports|Name
# Empower BI V3 - Copy - Copy - Copy Reports ParentID Reports|ParentID
# Empower BI V3 - Copy - Copy - Copy Reports Type Reports|Type
# Empower BI V3 - Copy - Copy - Copy Reports Property Reports|Property
# Empower BI V3 - Copy - Copy - Copy Reports Description Reports|Description
# Empower BI V3 - Copy - Copy - Copy Reports Hidden Reports|Hidden
# Empower BI V3 - Copy - Copy - Copy Reports CreatedByID Reports|CreatedByID
# Empower BI V3 - Copy - Copy - Copy Reports CreationDate Reports|CreationDate
# Empower BI V3 - Copy - Copy - Copy Reports ModifiedByID Reports|ModifiedByID
# Empower BI V3 - Copy - Copy - Copy Reports ModifiedDate Reports|ModifiedDate
# Empower BI V3 - Copy - Copy - Copy Reports MimeType Reports|MimeType
# Empower BI V3 - Copy - Copy - Copy Reports SnapshotLimit Reports|SnapshotLimit
# Empower BI V3 - Copy - Copy - Copy Reports Parameter Reports|Parameter
# Empower BI V3 - Copy - Copy - Copy Reports PolicyID Reports|PolicyID
# Empower BI V3 - Copy - Copy - Copy Reports PolicyRoot Reports|PolicyRoot
# Empower BI V3 - Copy - Copy - Copy Reports ExecutionFlag Reports|ExecutionFlag
# Empower BI V3 - Copy - Copy - Copy Reports ExecutionTime Reports|ExecutionTime
# Empower BI V3 - Copy - Copy - Copy Reports SubType Reports|SubType
# Empower BI V3 - Copy - Copy - Copy Reports ComponentID Reports|ComponentID
# Empower BI V3 - Copy - Copy - Copy Reports ContentSize Reports|ContentSize
# Empower BI V3 - Copy - Copy - Copy Reports LINK_REPORT_HASH Reports|LINK_REPORT_HASH
# Empower BI V3 - Copy - Copy - Copy Reports LINK_TO_MANAGE Reports|LINK_TO_MANAGE
# Empower BI V3 - Copy - Copy - Copy Reports LINK_TO_SERVER Reports|LINK_TO_SERVER
# Empower BI V3 - Copy - Copy - Copy Reports Size in MB Reports|Size in MB
# Empower BI V3 - Copy - Copy - Copy Reports Contains Visual Flash Reports|Contains Visual Flash
# Empower BI V3 - Copy - Copy - Copy Reports Server 2 Reports|Server 2
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 5 - VPAX Columns|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Table-Column 5 - VPAX Columns|Table-Column
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Rows 5 - VPAX Columns|Rows
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Cardinality 5 - VPAX Columns|Cardinality
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Col Size 5 - VPAX Columns|Col Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Data 5 - VPAX Columns|Data
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Dictionary 5 - VPAX Columns|Dictionary
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Hier Size 5 - VPAX Columns|Hier Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns % Table 5 - VPAX Columns|% Table
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns % DB 5 - VPAX Columns|% DB
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Encoding 5 - VPAX Columns|Encoding
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Data Type 5 - VPAX Columns|Data Type
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Partitions 5 - VPAX Columns|Partitions
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Segments 5 - VPAX Columns|Segments
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Pageable 5 - VPAX Columns|Pageable
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Resident 5 - VPAX Columns|Resident
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Temperature 5 - VPAX Columns|Temperature
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Last accessed 5 - VPAX Columns|Last accessed
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Column Name 5 - VPAX Columns|Column Name
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Columns Size in MB 5 - VPAX Columns|Size in MB
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 5 - VPAX Partitions|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Table / Partition 5 - VPAX Partitions|Table / Partition
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Rows 5 - VPAX Partitions|Rows
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Data 5 - VPAX Partitions|Data
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Partitions 5 - VPAX Partitions|Partitions
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Segments 5 - VPAX Partitions|Segments
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Tot. Seg. 5 - VPAX Partitions|Tot. Seg.
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Pageable 5 - VPAX Partitions|Pageable
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Resident 5 - VPAX Partitions|Resident
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Temperature 5 - VPAX Partitions|Temperature
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Partitions Last accessed 5 - VPAX Partitions|Last accessed
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 5 - VPAX Relationships|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Table / Relationship 5 - VPAX Relationships|Table / Relationship
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Size 5 - VPAX Relationships|Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Max From Cardinality 5 - VPAX Relationships|Max From Cardinality
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Max To Cardinality 5 - VPAX Relationships|Max To Cardinality
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships 1:M Ratio % 5 - VPAX Relationships|1:M Ratio %
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Missing Keys 5 - VPAX Relationships|Missing Keys
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Invalid Rows 5 - VPAX Relationships|Invalid Rows
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Relationships Sample Violations 5 - VPAX Relationships|Sample Violations
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 5 - VPAX Tables|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Name 5 - VPAX Tables|Name
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Cardinality 5 - VPAX Tables|Cardinality
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Total Size 5 - VPAX Tables|Total Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Data 5 - VPAX Tables|Data
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Dictionary 5 - VPAX Tables|Dictionary
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Hier Size 5 - VPAX Tables|Hier Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Encoding 5 - VPAX Tables|Encoding
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Data Type 5 - VPAX Tables|Data Type
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables RI Violations 5 - VPAX Tables|RI Violations
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables User Hier Size 5 - VPAX Tables|User Hier Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Rel Size 5 - VPAX Tables|Rel Size
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables % Table 5 - VPAX Tables|% Table
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables % DB 5 - VPAX Tables|% DB
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Columns 5 - VPAX Tables|Columns
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Partitions 5 - VPAX Tables|Partitions
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Segments 5 - VPAX Tables|Segments
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Pageable 5 - VPAX Tables|Pageable
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Resident 5 - VPAX Tables|Resident
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Temperature 5 - VPAX Tables|Temperature
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Last accessed 5 - VPAX Tables|Last accessed
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Table Name 5 - VPAX Tables|Table Name
# Empower BI V3 - Copy - Copy - Copy 5 - VPAX Tables Size in MB 5 - VPAX Tables|Size in MB
# Empower BI V3 - Copy - Copy - Copy Extracted Power Query Steps RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61 Extracted Power Query Steps|RowNumber-2662979B-1795-4F74-8F37-6A1BA8059B61
# Empower BI V3 - Copy - Copy - Copy Extracted Power Query Steps nan Extracted Power Query Steps|nan
# Empower BI V3 - Copy - Copy - Copy Tablas # Automatic Date-Tables Tablas|# Automatic Date-Tables
# Empower BI V3 - Copy - Copy - Copy Tablas Tables Tablas|Tables
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Basic Column Columnas Y Metricas|Basic Column
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas # Measures Columnas Y Metricas|# Measures
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Calculated Column Columnas Y Metricas|Calculated Column
# Empower BI V3 - Copy - Copy - Copy Columnas Y Metricas Total Columns Columnas Y Metricas|Total Columns
# Empower BI V3 - Copy - Copy - Copy Partitions SourceTypeSummary Partitions|SourceTypeSummary
# Análisis Jerárquico de dependencias:
#
# Columnas Base (Directas de bajada):
# HR Headcount[# Trámites 2_]
#                                 reporte  ...                                      Referencias 2
# 0    Empower BI V3 - Copy - Copy - Copy  ...
# 1    Empower BI V3 - Copy - Copy - Copy  ...                               Columnas[Expression]
# 2    Empower BI V3 - Copy - Copy - Copy  ...
# 3    Empower BI V3 - Copy - Copy - Copy  ...
# 4    Empower BI V3 - Copy - Copy - Copy  ...
# ..                                  ...  ...                                                ...
# 247  Empower BI V3 - Copy - Copy - Copy  ...  Columnas Y Metricas[Nombre],Columnas Y Metrica...
# 248  Empower BI V3 - Copy - Copy - Copy  ...  Columnas Y Metricas[Nombre],Columnas Y Metrica...
# 249  Empower BI V3 - Copy - Copy - Copy  ...  Columnas Y Metricas[Nombre],Columnas Y Metrica...
# 250  Empower BI V3 - Copy - Copy - Copy  ...  Columnas Y Metricas[Nombre],Columnas Y Metrica...
# 251  Empower BI V3 - Copy - Copy - Copy  ...  Partitions[Count],Partitions[Count],Partitions...
#
# [252 rows x 5 columns]
# Tiempo de ejecución: 0.45 segundos
# [CREADO] Archivo: C:\Users\Administrator\DMV Automation\DMV Files\testUser + Empower BI V3 - Copy - Copy - Copy + analisis de dependencias.xlsx
#
# 🔸 STDERR:
# C:\Users\Administrator\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Administrator\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Administrator\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
ejecutar_script(r"C:\Users\Administrator\DMV Automation\Two_B_Consolidacion.py")
# Out:
# 🚀 Ejecutando: C:\Users\Administrator\DMV Automation\Two_B_Consolidacion.py
# ✅ Script ejecutado correctamente.
# 🔹 STDOUT:
#
# 📊 Reporte: Empower BI V3 - Copy - Copy - Copy
#   - testUser + Empower BI V3 - Copy - Copy - Copy + analisis de dependencias.xlsx
#
# 📊 Reporte: Empower BI V4
#   - testUser + Empower BI V4 + analisis de dependencias.xlsx
#   - testUser + Empower BI V4 + columnas.xlsx
#   - testUser + Empower BI V4 + metricas.xlsx
#   - testUser + Empower BI V4 + partitions.xlsx
#   - testUser + Empower BI V4 + relaciones.xlsx
#   - testUser + Empower BI V4 + tablas.xlsx
#
# 📊 Reporte: Plantilla Empower BI
#   - testUser + Plantilla Empower BI + analisis de dependencias.xlsx
#   - testUser + Plantilla Empower BI + columnas.xlsx
#   - testUser + Plantilla Empower BI + metricas.xlsx
#   - testUser + Plantilla Empower BI + partitions.xlsx
#   - testUser + Plantilla Empower BI + relaciones.xlsx
#   - testUser + Plantilla Empower BI + tablas.xlsx
#
# 📊 Reporte: Plantilla Empower BI V4
#   - testUser + Plantilla Empower BI V4 + columnas.xlsx
#   - testUser + Plantilla Empower BI V4 + metricas.xlsx
#   - testUser + Plantilla Empower BI V4 + partitions.xlsx
#   - testUser + Plantilla Empower BI V4 + relaciones.xlsx
#   - testUser + Plantilla Empower BI V4 + tablas.xlsx
#
# 📊 Reporte: Reporte Nutrición V9
#   - testUser + Reporte Nutrición V9 + analisis de dependencias.xlsx
#   - testUser + Reporte Nutrición V9 + columnas.xlsx
#   - testUser + Reporte Nutrición V9 + metricas.xlsx
#   - testUser + Reporte Nutrición V9 + partitions.xlsx
#   - testUser + Reporte Nutrición V9 + relaciones.xlsx
#   - testUser + Reporte Nutrición V9 + tablas.xlsx
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Empower BI V3 - Copy - Copy - Copy + analisis de dependencias.xlsx (252 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Empower BI V4 + analisis de dependencias.xlsx (255 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Empower BI V4 + columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Empower BI V4 + metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Empower BI V4 + partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Empower BI V4 + relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Empower BI V4 + tablas.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Plantilla Empower BI + analisis de dependencias.xlsx (97 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Plantilla Empower BI + columnas.xlsx (145 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Plantilla Empower BI + metricas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Plantilla Empower BI + partitions.xlsx (10 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Plantilla Empower BI + relaciones.xlsx (9 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Plantilla Empower BI + tablas.xlsx (10 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Plantilla Empower BI V4 + columnas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Plantilla Empower BI V4 + metricas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Plantilla Empower BI V4 + partitions.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Plantilla Empower BI V4 + relaciones.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Plantilla Empower BI V4 + tablas.xlsx (0 filas)
# [✓] Cargado archivo de tipo 'analisis de dependencias': testUser + Reporte Nutrición V9 + analisis de dependencias.xlsx (275 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser + Reporte Nutrición V9 + columnas.xlsx (162 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser + Reporte Nutrición V9 + metricas.xlsx (118 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser + Reporte Nutrición V9 + partitions.xlsx (19 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser + Reporte Nutrición V9 + relaciones.xlsx (15 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser + Reporte Nutrición V9 + tablas.xlsx (19 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser+Empower BI V3 - Copy - Copy - Copy+columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser+Empower BI V3 - Copy - Copy - Copy+metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser+Empower BI V3 - Copy - Copy - Copy+partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser+Empower BI V3 - Copy - Copy - Copy+relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser+Empower BI V3 - Copy - Copy - Copy+tablas.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'columnas': testUser+Empower BI V3+columnas.xlsx (315 filas)
# [✓] Cargado archivo de tipo 'metricas': testUser+Empower BI V3+metricas.xlsx (7 filas)
# [✓] Cargado archivo de tipo 'partitions': testUser+Empower BI V3+partitions.xlsx (21 filas)
# [✓] Cargado archivo de tipo 'relaciones': testUser+Empower BI V3+relaciones.xlsx (13 filas)
# [✓] Cargado archivo de tipo 'tablas': testUser+Empower BI V3+tablas.xlsx (21 filas)
# [📊] Unificado df_analisis de dependencias: 879 filas
# [📊] Unificado df_columnas: 1252 filas
# [📊] Unificado df_metricas: 139 filas
# [📊] Unificado df_partitions: 92 filas
# [📊] Unificado df_relaciones: 63 filas
# [📊] Unificado df_tablas: 92 filas
# [✓] Archivo Excel guardado exitosamente en: C:\Users\Administrator\DMV Automation\Archivos Consolidados\testUser - Consolidado.xlsx
#
# 🔸 STDERR:

# %%
ejecutar_script(r"C:\Users\Administrator\DMV Automation\Three_Cargar_Plantilla_Y_Publicar.py")
# Out:
# 🚀 Ejecutando: C:\Users\Administrator\DMV Automation\Three_Cargar_Plantilla_Y_Publicar.py
# ✅ Script ejecutado correctamente.
# 🔹 STDOUT:
# Controles encontrados:
# [0] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | Chrome_WidgetWin_0
# [2] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html' | Chrome_WidgetWin_1
# [3] Pane | '' | Intermediate D3D Window
# [4] Pane | '' | Intermediate D3D Window
# [5] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html - Web content' | BrowserRootView
# [6] Pane | '' | NonClientView
# [7] Pane | '' | EmbeddedBrowserTabRootView
# [8] Pane | '' | EmbeddedBrowserFrameView
# [9] Pane | '' | BrowserView
# [10] Pane | '' | TopContainerView
# [11] Pane | '' | SidebarContentsSplitView
# [12] Pane | '' | SidebarContentsSplitView
# [13] Pane | '' | View
# [14] Document | '' |
# [15] Group | '' | site-default theme-default v1 enable-motion ng-tns-0-1
# [16] Group | '' | themeableElement
# [17] ToolBar | 'Plantilla Empower BI' | titlebar themeableElement
# [18] Group | '' | leftCorner
# [19] Group | '' |
# [20] Group | '' | ms-Fabric root-224
# [21] Button | 'Save' | ms-Button root-226
# [22] Button | 'Undo' | ms-Button is-disabled root-228
# [23] Button | 'Redo' | ms-Button is-disabled root-228
# [24] Button | 'Plantilla Empower BI · Last saved: 7/1/2025 at 2:24 AM' | titleStatusContainer pbi-focus-outline ng-star-inserted
# [25] Text | 'Plantilla Empower BI' | title
# [26] Group | '' | ribbonSearch
# [27] Edit | '￼' | input-292
# [28] Text | '' | css-290
# [29] Text | '0 Suggestions available,' |
# [30] Group | '' |
# [31] Button | 'MARIANO SORBO (msorbo@uade.edu.ar) is signed in. Open for account details' | header
# [32] Group | '' | accountNameLabel
# [33] Image | 'To get missing image descriptions, open the context menu.' | imageAvatarIcon
# [34] Group | '' | windowControls
# [35] Group | '' | ms-Fabric root-224
# [36] TabItem | 'File' | ms-Button root-238
# [37] Group | 'Ribbon tabs' | ms-FocusZone css-136
# [38] Tab | '' | ms-OverflowSet root-137
# [39] TabItem | 'Home' | ms-Button root-240
# [40] TabItem | 'Insert' | ms-Button root-241
# [41] TabItem | 'Modeling' | ms-Button root-241
# [42] TabItem | 'View' | ms-Button root-241
# [43] TabItem | 'Optimize' | ms-Button root-241
# [44] TabItem | 'Help' | ms-Button root-241
# [45] TabItem | 'External tools' | ms-Button root-241
# [46] Button | 'Share' | ms-Button ms-Button--hasMenu rootHasMenu-319
# [47] Text | 'Share' |
# [48] Text | 'Share this document, and see who it's shared with.' |
# [49] Pane | '' | root-246 bottomBarContainer
# [50] Group | 'Clipboard' | root-156
# [51] Button | 'Paste' | ms-Button is-disabled root-248
# [52] Button | 'Cut' | ms-Button is-disabled root-300
# [53] Button | 'Copy' | ms-Button is-disabled root-300
# [54] Button | 'Format painter' | ms-Button is-disabled root-300
# [55] Text | 'Like the formatting of something in your document? Use Format painter to apply that look to other content. 1. Select content with formatting you like. 2. On the Home tab, choose Format painter. 3. Select something else to apply the formatting.' |
# [56] Text | 'Clipboard' |
# [57] Group | 'Data' | root-156
# [58] Button | 'Get data' | splitButtonContainer-272
# [59] Button | 'Get data' | splitPrimaryButton root-256
# [60] Button | 'Get data' | ms-Button splitMenuButton splitButtonMenuButton-259
# [61] Text | 'Get' |
# [62] Text | 'data' |
# [63] Button | 'Excel workbook' | ms-Button root-301
# [64] Button | 'OneLake ​​catalog' | splitButtonContainer-314
# [65] Button | 'OneLake ​​catalog' | splitPrimaryButton root-303
# [66] Button | '' | ms-Button splitMenuButton splitButtonMenuButton-305
# [67] Button | 'SQL Server' | ms-Button root-301
# [68] Button | 'Enter data' | ms-Button root-301
# [69] Button | 'Dataverse' | ms-Button root-301
# [70] Button | 'Recent sources' | ms-Button ms-Button--hasMenu root-316
# [71] Text | 'Recent sources' |
# [72] Text | 'Manage and connect to recent sources.' |
# [73] Text | 'Data' |
# [74] Group | 'Queries' | root-156
# [75] Button | 'Transform data' | splitButtonContainer-272
# [76] Button | 'Transform data' | splitPrimaryButton root-256
# [77] Button | 'Transform data' | ms-Button splitMenuButton splitButtonMenuButton-259
# [78] Text | 'Transform' |
# [79] Text | 'data' |
# [80] Button | 'Refresh' | ms-Button root-274
# [81] Text | 'Queries' |
# [82] Group | 'Insert' | root-156
# [83] Button | 'New visual' | ms-Button root-274
# [84] Button | 'Text box' | ms-Button root-274
# [85] Button | 'More visuals' | splitButtonContainer-272
# [86] Button | 'More visuals' | splitPrimaryButton root-256
# [87] Button | 'More visuals' | ms-Button splitMenuButton splitButtonMenuButton-259
# [88] Text | 'More' |
# [89] Text | 'visuals' |
# [90] Text | 'Insert' |
# [91] Group | 'Calculations' | root-156
# [92] Button | 'New visual calculation' | splitButtonContainerDisabled-297
# [93] Button | 'New visual calculation' | splitPrimaryButton root-293
# [94] Button | 'New visual calculation' | ms-Button splitMenuButton is-disabled splitButtonMenuButtonDisabled-296
# [95] Text | 'New visual' |
# [96] Text | 'calculation' |
# [97] Button | 'New measure' | ms-Button root-274
# [98] Button | 'Quick measure' | ms-Button root-274
# [99] Text | 'Calculations' |
# [100] Group | 'Sensitivity' | root-156
# [101] Button | 'Sensitivity' | ms-Button ms-Button--hasMenu is-disabled root-278
# [102] Text | 'Sensitivity' |
# [103] Text | 'Apply a label to classify the sensitivity of your report and protect its content.' |
# [104] Text | 'Sensitivity' |
# [105] Group | 'Share' | root-156
# [106] Button | 'Publish' | ms-Button root-274
# [107] Text | 'Share' |
# [108] Group | 'Copilot' | root-156
# [109] Button | 'Prep data for AI' | ms-Button root-274
# [110] Button | 'Copilot' | ms-Button .ignore-legacy-styles root-274
# [111] Text | 'Copilot' |
# [112] Button | 'Switch ribbons' | ms-Button root-280
# [113] Tab | '' | viewNavigatorContainer themeableElement
# [114] TabItem | 'Report view' | selected
# [115] Image | '' |
# [116] TabItem | 'Table view' |
# [117] Image | '' |
# [118] TabItem | 'Model view' |
# [119] Image | '' |
# [120] TabItem | 'DAX query view' |
# [121] Image | '' |
# [122] StatusBar | '<b>Upgrade Power BI Desktop:</b> The 32-bit version will no longer be supported after 7/31/2025. Upgrade to the 64-bit version for continued support and updates. ' | message-banner bar-default-border message-banner-warning
# [123] Text | 'Upgrade Power BI Desktop:' |
# [124] Text | ' The 32-bit version will no longer be supported after 7/31/2025. Upgrade to the 64-bit version for continued support and updates. ' |
# [125] Button | 'Close' | dismiss-button svg-button
# [126] Button | 'Upgrade' | action-button
# [127] StatusBar | 'Auto recovery contains some recovered files that haven't been opened. ' | message-banner bar-default-border message-banner-info
# [128] Text | 'Auto recovery contains some recovered files that haven't been opened. ' |
# [129] Button | 'View recovered files' | action-button
# [130] Button | 'Close' | dismiss-button svg-button
# [131] Group | '' |
# [132] Pane | '' | fieldListPane
# [133] Button | 'Data' | toggle-button
# [134] Text | 'Data' | pane-title fluentTheme-lg-semiBold
# [135] Group | '' | paneStopBottom
# [136] Text | 'Page 1 of 1' |
# [137] Group | '' | updateAvailableSlot
# [138] Text | 'Update available (click to download)' |
# [139] Button | 'Zoom Out' | zoomButton
# [140] Group | '' | slider themeableElement
# [141] Group | '' | zoomHandle
# [142] Button | 'Zoom In' | zoomButton
# [143] Button | 'Zoom level. Click to open the Zoom dialog box' | zoomValue imageButton buttonHover
# [144] Button | 'Fit to page' | smallImageButton
# [145] Text | 'Power BI Desktop' |
# [146] Group | '' | cdk-live-announcer-element cdk-visually-hidden
# [147] Text | '' | monaco-alert
# [148] Text | '' | monaco-alert
# [149] Group | '' | monaco-status
# [150] Group | '' | monaco-status
# [151] Group | '' | ms-Fabric ms-Layer-content content-283
# [152] Group | '' | ms-Fabric ms-Layer-content content-283
# [153] Group | '' | ms-Fabric ms-Layer-content content-283
# [154] Group | '' | ms-Fabric ms-Layer-content content-283
# [155] Group | '' | ms-Fabric ms-Layer-content content-283
# [156] Group | '' | ms-Fabric ms-Layer-content content-283
# [157] Text | '' |
# [158] Text | 'Report Zoomed To 61%' |
# [159] Pane | '' | EmbeddedBrowserDownloadView
# [160] Pane | '' | TopContainerOverlayView
# [161] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [162] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [163] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [164] TitleBar | '' |
# [165] MenuBar | 'System' |
# [166] MenuItem | 'System' |
# [167] Button | 'Minimize' |
# [168] Button | 'Restore' |
# [169] Button | 'Close' |
#
# [0] Title: Plantilla Empower BI | Class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# Controles encontrados:
# [0] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | Chrome_WidgetWin_0
# [2] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html' | Chrome_WidgetWin_1
# [3] Pane | '' | Intermediate D3D Window
# [4] Pane | '' | Intermediate D3D Window
# [5] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html - Web content' | BrowserRootView
# [6] Pane | '' | NonClientView
# [7] Pane | '' | EmbeddedBrowserTabRootView
# [8] Pane | '' | EmbeddedBrowserFrameView
# [9] Pane | '' | BrowserView
# [10] Pane | '' | TopContainerView
# [11] Pane | '' | SidebarContentsSplitView
# [12] Pane | '' | SidebarContentsSplitView
# [13] Pane | '' | View
# [14] Document | '' |
# [15] Group | '' | site-default theme-default v1 enable-motion ng-tns-0-1
# [16] Group | '' | themeableElement
# [17] ToolBar | 'Plantilla Empower BI' | titlebar themeableElement
# [18] Group | '' | leftCorner
# [19] Group | '' |
# [20] Group | '' | ms-Fabric root-224
# [21] Button | 'Save' | ms-Button root-226
# [22] Button | 'Undo' | ms-Button is-disabled root-228
# [23] Button | 'Redo' | ms-Button is-disabled root-228
# [24] Button | 'Plantilla Empower BI · Last saved: 7/1/2025 at 2:24 AM' | titleStatusContainer pbi-focus-outline ng-star-inserted
# [25] Text | 'Plantilla Empower BI' | title
# [26] Group | '' | ribbonSearch
# [27] Edit | '￼' | input-292
# [28] Text | '' | css-290
# [29] Text | '0 Suggestions available,' |
# [30] Group | '' |
# [31] Button | 'MARIANO SORBO (msorbo@uade.edu.ar) is signed in. Open for account details' | header
# [32] Group | '' | accountNameLabel
# [33] Image | 'To get missing image descriptions, open the context menu.' | imageAvatarIcon
# [34] Group | '' | windowControls
# [35] Group | '' | ms-Fabric root-224
# [36] TabItem | 'File' | ms-Button root-238
# [37] Group | 'Ribbon tabs' | ms-FocusZone css-136
# [38] Tab | '' | ms-OverflowSet root-137
# [39] TabItem | 'Home' | ms-Button root-240
# [40] TabItem | 'Insert' | ms-Button root-241
# [41] TabItem | 'Modeling' | ms-Button root-241
# [42] TabItem | 'View' | ms-Button root-241
# [43] TabItem | 'Optimize' | ms-Button root-241
# [44] TabItem | 'Help' | ms-Button root-241
# [45] TabItem | 'External tools' | ms-Button root-241
# [46] Button | 'Share' | ms-Button ms-Button--hasMenu rootHasMenu-319
# [47] Text | 'Share' |
# [48] Text | 'Share this document, and see who it's shared with.' |
# [49] Pane | '' | root-246 bottomBarContainer
# [50] Group | 'Clipboard' | root-156
# [51] Button | 'Paste' | ms-Button is-disabled root-248
# [52] Button | 'Cut' | ms-Button is-disabled root-300
# [53] Button | 'Copy' | ms-Button is-disabled root-300
# [54] Button | 'Format painter' | ms-Button is-disabled root-300
# [55] Text | 'Like the formatting of something in your document? Use Format painter to apply that look to other content. 1. Select content with formatting you like. 2. On the Home tab, choose Format painter. 3. Select something else to apply the formatting.' |
# [56] Text | 'Clipboard' |
# [57] Group | 'Data' | root-156
# [58] Button | 'Get data' | splitButtonContainer-272
# [59] Button | 'Get data' | splitPrimaryButton root-256
# [60] Button | 'Get data' | ms-Button splitMenuButton splitButtonMenuButton-259
# [61] Text | 'Get' |
# [62] Text | 'data' |
# [63] Button | 'Excel workbook' | ms-Button root-301
# [64] Button | 'OneLake ​​catalog' | splitButtonContainer-314
# [65] Button | 'OneLake ​​catalog' | splitPrimaryButton root-303
# [66] Button | '' | ms-Button splitMenuButton splitButtonMenuButton-305
# [67] Button | 'SQL Server' | ms-Button root-301
# [68] Button | 'Enter data' | ms-Button root-301
# [69] Button | 'Dataverse' | ms-Button root-301
# [70] Button | 'Recent sources' | ms-Button ms-Button--hasMenu root-316
# [71] Text | 'Recent sources' |
# [72] Text | 'Manage and connect to recent sources.' |
# [73] Text | 'Data' |
# [74] Group | 'Queries' | root-156
# [75] Button | 'Transform data' | splitButtonContainer-272
# [76] Button | 'Transform data' | splitPrimaryButton root-256
# [77] Button | 'Transform data' | ms-Button splitMenuButton splitButtonMenuButton-259
# [78] Text | 'Transform' |
# [79] Text | 'data' |
# [80] Button | 'Refresh' | ms-Button root-274
# [81] Text | 'Queries' |
# [82] Group | 'Insert' | root-156
# [83] Button | 'New visual' | ms-Button root-274
# [84] Button | 'Text box' | ms-Button root-274
# [85] Button | 'More visuals' | splitButtonContainer-272
# [86] Button | 'More visuals' | splitPrimaryButton root-256
# [87] Button | 'More visuals' | ms-Button splitMenuButton splitButtonMenuButton-259
# [88] Text | 'More' |
# [89] Text | 'visuals' |
# [90] Text | 'Insert' |
# [91] Group | 'Calculations' | root-156
# [92] Button | 'New visual calculation' | splitButtonContainerDisabled-297
# [93] Button | 'New visual calculation' | splitPrimaryButton root-293
# [94] Button | 'New visual calculation' | ms-Button splitMenuButton is-disabled splitButtonMenuButtonDisabled-296
# [95] Text | 'New visual' |
# [96] Text | 'calculation' |
# [97] Button | 'New measure' | ms-Button root-274
# [98] Button | 'Quick measure' | ms-Button root-274
# [99] Text | 'Calculations' |
# [100] Group | 'Sensitivity' | root-156
# [101] Button | 'Sensitivity' | ms-Button ms-Button--hasMenu is-disabled root-278
# [102] Text | 'Sensitivity' |
# [103] Text | 'Apply a label to classify the sensitivity of your report and protect its content.' |
# [104] Text | 'Sensitivity' |
# [105] Group | 'Share' | root-156
# [106] Button | 'Publish' | ms-Button root-274
# [107] Text | 'Share' |
# [108] Group | 'Copilot' | root-156
# [109] Button | 'Prep data for AI' | ms-Button root-274
# [110] Button | 'Copilot' | ms-Button .ignore-legacy-styles root-274
# [111] Text | 'Copilot' |
# [112] Button | 'Switch ribbons' | ms-Button root-280
# [113] Tab | '' | viewNavigatorContainer themeableElement
# [114] TabItem | 'Report view' | selected
# [115] Image | '' |
# [116] TabItem | 'Table view' |
# [117] Image | '' |
# [118] TabItem | 'Model view' |
# [119] Image | '' |
# [120] TabItem | 'DAX query view' |
# [121] Image | '' |
# [122] StatusBar | '<b>Upgrade Power BI Desktop:</b> The 32-bit version will no longer be supported after 7/31/2025. Upgrade to the 64-bit version for continued support and updates. ' | message-banner bar-default-border message-banner-warning
# [123] Text | 'Upgrade Power BI Desktop:' |
# [124] Text | ' The 32-bit version will no longer be supported after 7/31/2025. Upgrade to the 64-bit version for continued support and updates. ' |
# [125] Button | 'Close' | dismiss-button svg-button
# [126] Button | 'Upgrade' | action-button
# [127] StatusBar | 'Auto recovery contains some recovered files that haven't been opened. ' | message-banner bar-default-border message-banner-info
# [128] Text | 'Auto recovery contains some recovered files that haven't been opened. ' |
# [129] Button | 'View recovered files' | action-button
# [130] Button | 'Close' | dismiss-button svg-button
# [131] Pane | '' | exploration
# [132] List | '' | accessibility-info-items
# [133] ListItem | 'Show keyboard shortcuts' |
# [134] Button | 'Show keyboard shortcuts' | link pbi-focus-outline
# [135] ListItem | 'Show screen reader tips' |
# [136] Hyperlink | 'Show screen reader tips (opens in new tab)' |
# [137] Image | '' |
# [138] ListItem | 'Skip to main content' |
# [139] Button | 'Skip to main content' | link pbi-focus-outline
# [140] Group | '' | displayAreaContainer newCanvasScrollbar droppableElement ui-droppable
# [141] Group | 'Power BI Report' | visualContainerHost visualContainerOutOfFocus
# [142] Text | 'Power BI Report' |
# [143] Group | '' | selectThrough transformElement
# [144] Group | '6 items' | visualContainerGroup unselectable
# [145] Group | '' |
# [146] Group | '' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [147] Group | '' |
# [148] Group | '' |
# [149] Group | '' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [150] Group | '' |
# [151] Group | '' |
# [152] Group | '' | visualContainer unselectable editMode noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [153] Group | '' |
# [154] Group | '' | textboxFocusElement
# [155] Group | 'Reports Documentation | Columns and Measures' | ql-editor
# [156] Text | 'Reports Documentation ' |
# [157] Text | '| Columns and Measures' |
# [158] Group | '￼' | ql-clipboard
# [159] Group | '' |
# [160] Group | '' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [161] Group | '' |
# [162] Group | '' |
# [163] Group | '' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [164] Group | '' |
# [165] Group | '' |
# [166] Group | '' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [167] Group | '' |
# [168] Group | '' | bringToFront transformElement
# [169] Group | 'Back . CTRL+click here to go back to the previous page in this report' | visualContainer unselectable editMode paddingDisabled noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [170] Group | '' |
# [171] Group | '' | bringToFront transformElement
# [172] Group | '' | visualContainer unselectable editMode noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [173] Group | '' |
# [174] Text | 'Report' | slicer-header-text
# [175] Button | 'This setting has moved. To change the slicer style, open the Format pane and select Slicer settings > Options > Style.' | slicer-helper-tooltip-button
# [176] ComboBox | 'Report' | slicer-dropdown-menu
# [177] Text | 'All' |
# [178] Text | '' |
# [179] Group | '' | bringToFront transformElement
# [180] Group | '' | visualContainer unselectable editMode noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [181] Group | '' |
# [182] Text | 'Table' | slicer-header-text
# [183] Button | 'This setting has moved. To change the slicer style, open the Format pane and select Slicer settings > Options > Style.' | slicer-helper-tooltip-button
# [184] ComboBox | 'Name' | slicer-dropdown-menu
# [185] Text | 'All' |
# [186] Text | '' |
# [187] Group | '' | bringToFront transformElement
# [188] Group | '' | visualContainer unselectable editMode noVisualTitle droppableElement ui-droppable visualHeaderBelow
# [189] Group | '' |
# [190] Text | 'Column or Measure' | slicer-header-text
# [191] Button | 'This setting has moved. To change the slicer style, open the Format pane and select Slicer settings > Options > Style.' | slicer-helper-tooltip-button
# [192] ComboBox | 'Name' | slicer-dropdown-menu
# [193] Text | 'All' |
# [194] Text | '' |
# [195] Group | '' | bringToFront transformElement
# [196] Group | '' | visualContainer unselectable editMode noVisualTitle droppableElement ui-droppable visualHeaderAbove
# [197] Group | '' |
# [198] Document | '' | tableEx
# [199] Button | 'Scroll up' | scrollUp visually-hidden
# [200] Button | 'Scroll down' | scrollDown visually-hidden
# [201] Button | 'Scroll left' | scrollLeft visually-hidden
# [202] Button | 'Scroll right' | scrollRight visually-hidden
# [203] DataGrid | '' | interactive-grid innerContainer
# [204] Text | 'Filters' | hiddenHeading
# [205] Button | 'Show/hide filter pane' | btn toggleBtn pbi-borderless-button
# [206] Button | 'Collapse or expand the filter pane while editing. This also determines how report readers see it' | btn collapseIcon pbi-borderless-button glyphicon glyph-mini pbi-glyph-doublechevronleft
# [207] Group | '' | editing explorationNavigationContent unselectable
# [208] Button | 'Desktop layout' | switcher-btn active trident-disabled pbi-focus-outline
# [209] Image | 'Desktop layout' | glyphicon pbi-glyph-tvmonitor trident-disabled ng-star-inserted
# [210] Button | 'Mobile layout' | switcher-btn trident-disabled
# [211] Image | 'Mobile layout' | glyphicon pbi-glyph-phone trident-disabled ng-star-inserted
# [212] ToolBar | '' | navButtonContainer
# [213] Button | 'Previous pages' | carouselNavButton previousPage
# [214] Button | 'Next pages' | carouselNavButton nextPage
# [215] Tab | '' | carouselScrollPane
# [216] TabItem | 'Columns & Measures' | section dynamic thumbnail-container selected ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [217] TabItem | 'Duplicado de Columns & Measures' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [218] TabItem | 'Tables' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [219] TabItem | 'Relationships' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [220] TabItem | 'Página 1' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [221] TabItem | 'SUPPORT' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [222] TabItem | 'Duplicado de Columns & Measures' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [223] TabItem | 'Página 3' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [224] TabItem | 'Página 4' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [225] TabItem | 'Página 5' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [226] TabItem | 'Página 2' | section dynamic thumbnail-container ui-draggable ui-draggable-handle pbi-focus-outline droppableElement ui-droppable
# [227] Button | 'New page' | section static create
# [228] Image | '' |
# [229] Group | '' |
# [230] Button | 'Visualizations' | toggle-button ng-star-inserted
# [231] Text | 'Visualizations' | pane-title fluentTheme-lg-semiBold
# [232] Text | 'Build visual' |
# [233] Tab | '' | ng-star-inserted
# [234] TabItem | 'Build visual' |
# [235] Group | '' | outer selected
# [236] Image | '' |
# [237] TabItem | 'Format page' |
# [238] Group | '' | outer
# [239] Image | '' |
# [240] Image | '' | select-indicator-bar
# [241] List | 'All visual types' | visual-types-container themeableElement ng-star-inserted
# [242] ListItem | 'Stacked bar chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [243] Image | '' |
# [244] ListItem | 'Stacked column chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [245] Image | '' |
# [246] ListItem | 'Clustered bar chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [247] Image | '' |
# [248] ListItem | 'Clustered column chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [249] Image | '' |
# [250] ListItem | '100% Stacked bar chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [251] Image | '' |
# [252] ListItem | '100% Stacked column chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [253] Image | '' |
# [254] ListItem | 'Line chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [255] Image | '' |
# [256] ListItem | 'Area chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [257] Image | '' |
# [258] ListItem | 'Stacked area chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [259] Image | '' |
# [260] ListItem | '100% Stacked area chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [261] Image | '' |
# [262] ListItem | 'Line and stacked column chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [263] Image | '' |
# [264] ListItem | 'Line and clustered column chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [265] Image | '' |
# [266] ListItem | 'Ribbon chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [267] Image | '' |
# [268] ListItem | 'Waterfall chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [269] Image | '' |
# [270] ListItem | 'Funnel' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [271] Image | '' |
# [272] ListItem | 'Scatter chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [273] Image | '' |
# [274] ListItem | 'Pie chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [275] Image | '' |
# [276] ListItem | 'Donut chart' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [277] Image | '' |
# [278] ListItem | 'Treemap' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [279] Image | '' |
# [280] ListItem | 'Map' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [281] Image | '' |
# [282] ListItem | 'Filled map' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [283] Image | '' |
# [284] ListItem | 'Azure map' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [285] Image | '' |
# [286] ListItem | 'Gauge' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [287] Image | '' |
# [288] ListItem | 'Card' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [289] Image | '' |
# [290] ListItem | 'Multi-row card' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [291] Image | '' |
# [292] ListItem | 'KPI' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [293] Image | '' |
# [294] ListItem | 'Slicer' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [295] Image | '' |
# [296] ListItem | 'Table' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [297] Image | '' |
# [298] ListItem | 'Matrix' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [299] Image | '' |
# [300] ListItem | 'R script visual' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [301] Image | '' |
# [302] ListItem | 'Python visual' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [303] Image | '' |
# [304] ListItem | 'Key influencers' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [305] Image | '' |
# [306] ListItem | 'Decomposition tree' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [307] Image | '' |
# [308] ListItem | 'Q&A' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [309] Image | '' |
# [310] ListItem | 'Narrative' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [311] Image | '' |
# [312] ListItem | 'Goals (Preview)' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [313] Image | '' |
# [314] ListItem | 'Paginated report' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [315] Image | '' |
# [316] ListItem | 'Card (new)' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [317] Image | '' |
# [318] ListItem | 'Button slicer' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [319] Image | '' |
# [320] ListItem | 'ArcGIS for Power BI' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [321] Image | '' |
# [322] ListItem | 'Power Apps for Power BI' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [323] Image | '' |
# [324] ListItem | 'Power Automate for Power BI' | visual-icon-container interactive pbi-menu-trigger ng-star-inserted
# [325] Image | '' |
# [326] ListItem | 'Get more visuals' | visual-icon-container more pbi-menu-trigger ng-star-inserted
# [327] List | '' | ng-star-inserted
# [328] ListItem | 'ValuesAdd data fields here' | field-well-bucket-element ng-star-inserted
# [329] Text | 'Values' | caption trimmedTextWithEllipsis smallFontSize
# [330] List | '' | properties droppableElement ui-droppable
# [331] ListItem | 'No data fields added. Add data fields here' | trimmedTextWithEllipsis dropzone droppableElement ui-droppable ng-star-inserted
# [332] Text | 'Drill through' | sectionHeader drillthroughSectionHeader
# [333] Text | 'Cross-report' |
# [334] Group | '' | pbi-toggle-button textbox compact
# [335] Button | 'Cross-report' | pbi-toggle-button-input cdk-visually-hidden
# [336] Text | 'Off' |
# [337] Text | 'Keep all filters' |
# [338] Group | '' | pbi-toggle-button textbox compact checked
# [339] Button | 'Keep all filters' | pbi-toggle-button-input cdk-visually-hidden
# [340] Text | 'On' |
# [341] List | '' | linkFieldFilters
# [342] List | '' | transientFilters
# [343] Group | '' | unselectable trimmedTextWithEllipsis dropzone
# [344] Text | 'Add drill-through fields here' |
# [345] Group | '' | paneStopBottom
# [346] Group | '' |
# [347] Pane | '' | fieldListPane
# [348] Button | 'Data' | toggle-button
# [349] Text | 'Data' | pane-title fluentTheme-lg-semiBold
# [350] Group | '' | container
# [351] Group | 'Search' | fluent-theme compact full-wdith
# [352] Edit | 'Search' |
# [353] Group | '' | cdk-virtual-scroll-viewport cdk-virtual-scrollable cdk-virtual-scroll-orientation-vertical
# [354] Tree | '' | cdk-tree
# [355] TreeItem | 'Calculated Table 6 - From Columns' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [356] Button | '6 - From Columns' | glyphicon expander ng-star-inserted
# [357] Image | '' |
# [358] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [359] TreeItem | 'Calculated Table 6 - From Tables' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [360] Button | '6 - From Tables' | glyphicon expander ng-star-inserted
# [361] Image | '' |
# [362] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [363] TreeItem | 'Calculated Table 6 - To Columns' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [364] Button | '6 - To Columns' | glyphicon expander ng-star-inserted
# [365] Image | '' |
# [366] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [367] TreeItem | 'Calculated Table 6 - To Tables' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [368] Button | '6 - To Tables' | glyphicon expander ng-star-inserted
# [369] Image | '' |
# [370] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [371] TreeItem | 'Table Columnas Y Metricas' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [372] Button | 'Columnas Y Metricas' | glyphicon expander ng-star-inserted
# [373] Image | '' |
# [374] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [375] TreeItem | 'Table Dependency Analysis' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [376] Button | 'Dependency Analysis' | glyphicon expander ng-star-inserted
# [377] Image | '' |
# [378] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [379] TreeItem | 'Calculated Table Distinct Reportes' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [380] Button | 'Distinct Reportes' | glyphicon expander ng-star-inserted
# [381] Image | '' |
# [382] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [383] TreeItem | 'Table Partitions' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [384] Button | 'Partitions' | glyphicon expander ng-star-inserted
# [385] Image | '' |
# [386] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [387] TreeItem | 'Table Relationships' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [388] Button | 'Relationships' | glyphicon expander ng-star-inserted
# [389] Image | '' |
# [390] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [391] TreeItem | 'Table Tablas' | cdk-tree-node pbi-focus-outline ng-star-inserted
# [392] Button | 'Tablas' | glyphicon expander ng-star-inserted
# [393] Image | '' |
# [394] Button | 'More options' | menu-button glyphicon glyph-mini pbi-glyph-more pbi-focus-outline-inset ng-star-inserted
# [395] Group | '' | paneStopBottom
# [396] Text | 'Page 1 of 11' |
# [397] Group | '' | updateAvailableSlot
# [398] Text | 'Update available (click to download)' |
# [399] Button | 'Zoom Out' | zoomButton
# [400] Group | '' | slider themeableElement
# [401] Group | '' | zoomHandle
# [402] Button | 'Zoom In' | zoomButton
# [403] Button | 'Zoom level. Click to open the Zoom dialog box' | zoomValue imageButton buttonHover
# [404] Button | 'Fit to page' | smallImageButton
# [405] Text | 'Power BI Desktop' |
# [406] Group | '' | cdk-live-announcer-element cdk-visually-hidden
# [407] Text | '' | monaco-alert
# [408] Text | '' | monaco-alert
# [409] Group | '' | monaco-status
# [410] Group | '' | monaco-status
# [411] Group | '' | ms-Fabric ms-Layer-content content-283
# [412] Group | '' | ms-Fabric ms-Layer-content content-283
# [413] Group | '' | ms-Fabric ms-Layer-content content-283
# [414] Group | '' | ms-Fabric ms-Layer-content content-283
# [415] Group | '' | ms-Fabric ms-Layer-content content-283
# [416] Group | '' | ms-Fabric ms-Layer-content content-283
# [417] Text | '' |
# [418] Text | '10 results. Report Zoomed To 35%' |
# [419] Image | '' |
# [420] Pane | '' | EmbeddedBrowserDownloadView
# [421] Pane | '' | TopContainerOverlayView
# [422] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [423] Pane | '' | Chrome_WidgetWin_0
# [424] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html' | Chrome_WidgetWin_1
# [425] Pane | '' | Intermediate D3D Window
# [426] Pane | '' | Intermediate D3D Window
# [427] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html - Web content' | BrowserRootView
# [428] Pane | '' | NonClientView
# [429] Pane | '' | EmbeddedBrowserTabRootView
# [430] Pane | '' | EmbeddedBrowserFrameView
# [431] Pane | '' | BrowserView
# [432] Pane | '' | TopContainerView
# [433] Pane | '' | SidebarContentsSplitView
# [434] Pane | '' | SidebarContentsSplitView
# [435] Pane | '' | View
# [436] Document | '' |
# [437] Pane | '' | EmbeddedBrowserDownloadView
# [438] Pane | '' | TopContainerOverlayView
# [439] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [440] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [441] TitleBar | '' |
# [442] MenuBar | 'System' |
# [443] MenuItem | 'System' |
# [444] Button | 'Minimize' |
# [445] Button | 'Restore' |
# [446] Button | 'Close' |
#
# Encontrados 8 botones con título 'Transform data':
#
# [0] Class: splitButtonContainer-272, Rect: (L393, T73, R451, B147), Handle: None
# [1] Class: splitPrimaryButton root-256, Rect: (L393, T73, R451, B110), Handle: None
# [2] Class: ms-Button splitMenuButton splitButtonMenuButton-259, Rect: (L393, T109, R451, B147), Handle: None
# [3] Class: splitButtonContainer-272, Rect: (L393, T73, R451, B147), Handle: None
# [4] Class: splitPrimaryButton root-256, Rect: (L393, T73, R451, B110), Handle: None
# [5] Class: ms-Button splitMenuButton splitButtonMenuButton-259, Rect: (L393, T109, R451, B147), Handle: None
# [6] Class: splitButtonContainer-298, Rect: (L216, T70, R335, B95), Handle: None
# [7] Class: splitPrimaryButton root-303, Rect: (L216, T70, R323, B95), Handle: None
# ✅ 'Data source settings' clickeado.
# [0] Title: 'Plantilla Empower BI' | Class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [0] Window | 'Data source settings' | WindowsForms10.Window.20008.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [2] Pane | '' | Shell Embedding
# [3] Pane | '' | Shell DocObject View
# [4] Pane | 'ms-pbi://pbi.microsoft.com/Views/KoForm.htm' | Internet Explorer_Server
# [5] Pane | '' |
# [6] Pane | 'Data source settings' |
# [7] Pane | 'Data source settings' |
# [38] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [39] Pane | '' | Chrome_WidgetWin_0
# [40] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html' | Chrome_WidgetWin_1
# [41] Pane | '' | Intermediate D3D Window
# [42] Pane | '' | Intermediate D3D Window
# [43] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html - Web content' | BrowserRootView
# [44] Pane | '' | NonClientView
# [45] Pane | '' | EmbeddedBrowserTabRootView
# [46] Pane | '' | EmbeddedBrowserFrameView
# [47] Pane | '' | BrowserView
# [48] Pane | '' | TopContainerView
# [49] Pane | '' | SidebarContentsSplitView
# [50] Pane | '' | SidebarContentsSplitView
# [51] Pane | '' | View
# [87] Pane | '' | root-246 bottomBarContainer
# [169] Pane | '' | exploration
# [699] Pane | '' | fieldListPane
# [773] Pane | '' | EmbeddedBrowserDownloadView
# [774] Pane | '' | TopContainerOverlayView
# [775] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [776] Pane | '' | Chrome_WidgetWin_0
# [777] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html' | Chrome_WidgetWin_1
# [778] Pane | '' | Intermediate D3D Window
# [779] Pane | '' | Intermediate D3D Window
# [780] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html - Web content' | BrowserRootView
# [781] Pane | '' | NonClientView
# [782] Pane | '' | EmbeddedBrowserTabRootView
# [783] Pane | '' | EmbeddedBrowserFrameView
# [784] Pane | '' | BrowserView
# [785] Pane | '' | TopContainerView
# [786] Pane | '' | SidebarContentsSplitView
# [787] Pane | '' | SidebarContentsSplitView
# [788] Pane | '' | View
# [820] Pane | '' | root-246 bottomBarContainer
# [900] Pane | '' | fieldListPane
# [973] Pane | '' | EmbeddedBrowserDownloadView
# [974] Pane | '' | TopContainerOverlayView
# [975] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [976] Pane | '' | Chrome_WidgetWin_0
# [977] Pane | 'ms-pbi.pbi.microsoft.com/minerva/modelView.html' | Chrome_WidgetWin_1
# [978] Pane | '' | Intermediate D3D Window
# [979] Pane | '' | Intermediate D3D Window
# [980] Pane | 'ms-pbi.pbi.microsoft.com/minerva/modelView.html - Web content' | BrowserRootView
# [981] Pane | '' | NonClientView
# [982] Pane | '' | EmbeddedBrowserTabRootView
# [983] Pane | '' | EmbeddedBrowserFrameView
# [984] Pane | '' | BrowserView
# [985] Pane | '' | TopContainerView
# [986] Pane | '' | SidebarContentsSplitView
# [987] Pane | '' | SidebarContentsSplitView
# [988] Pane | '' | View
# [1020] Pane | '' | root-246 bottomBarContainer
# [1323] Pane | '' | EmbeddedBrowserDownloadView
# [1324] Pane | '' | TopContainerOverlayView
# [1325] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1326] Pane | '' | Chrome_WidgetWin_0
# [1327] Pane | 'ms-pbi.pbi.microsoft.com/minerva/daxQueryView.html' | Chrome_WidgetWin_1
# [1328] Pane | '' | Intermediate D3D Window
# [1329] Pane | '' | Intermediate D3D Window
# [1330] Pane | 'ms-pbi.pbi.microsoft.com/minerva/daxQueryView.html - Web content' | BrowserRootView
# [1331] Pane | '' | NonClientView
# [1332] Pane | '' | EmbeddedBrowserTabRootView
# [1333] Pane | '' | EmbeddedBrowserFrameView
# [1334] Pane | '' | BrowserView
# [1335] Pane | '' | TopContainerView
# [1336] Pane | '' | SidebarContentsSplitView
# [1337] Pane | '' | SidebarContentsSplitView
# [1338] Pane | '' | View
# [1371] Pane | '' | root-210 bottomBarContainer
# [1497] Window | 'Run DAX queries on your model' | mat-mdc-dialog-container mdc-dialog cdk-dialog-container mdc-dialog--open _mat-animation-noopable
# [1511] Pane | '' | EmbeddedBrowserDownloadView
# [1512] Pane | '' | TopContainerOverlayView
# Controles en la ventana 'Data source settings':
# [0] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | Shell Embedding
# [2] Pane | '' | Shell DocObject View
# [3] Pane | 'ms-pbi://pbi.microsoft.com/Views/KoForm.htm' | Internet Explorer_Server
# [4] Pane | '' |
# [5] Pane | 'Data source settings' |
# [6] Pane | 'Data source settings' |
# [7] Text | 'Data source settings' |
# [8] Text | 'Data source settings' |
# [9] Button | 'Close' |
# [10] Text | 'Manage settings for data sources that you have connected to using Power BI Desktop.' |
# [11] List | '' |
# [12] RadioButton | 'Data sources in current file' |
# [13] Group | 'Data sources in current file' |
# [14] Text | 'Data sources in current file' |
# [15] RadioButton | 'Global permissions' |
# [16] Group | 'Global permissions' |
# [17] Text | 'Global permissions' |
# [18] Edit | 'Search data source settings' |
# [19] Button | 'Choose a sort type' |
# [20] Text | '' |
# [21] List | '' |
# [22] ListItem | 'c:\users\administrator\dmv aut...os\testuser - consolidado.xlsx' |
# [23] Text | 'c:\users\administrator\dmv aut...os\testuser - consolidado.xlsx' |
# [24] Button | 'Change Source...' |
# [25] Text | 'Change Source...' |
# [26] Button | 'Export PBIDS' |
# [27] Text | 'Export PBIDS' |
# [28] Button | 'Edit Permissions...' |
# [29] Text | 'Edit Permissions...' |
# [30] Button | 'Clear Permissions' |
# [31] Text | 'Clear Permissions' |
# [32] Button | 'More Options' |
# [33] Button | 'Edit Tables' |
# [34] Text | 'Edit Tables' |
# [35] Button | 'Close' |
# [36] Text | 'Close' |
# ✅ Click en 'Change Source...' realizado.
# [0] Window | 'Data source settings' | WindowsForms10.Window.20008.app.0.10f7c6e_r7_ad1
# [1] Window | 'Excel Workbook' | WindowsForms10.Window.20008.app.0.10f7c6e_r7_ad1
# [2] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [3] Pane | '' | Shell Embedding
# [4] Pane | '' | Shell DocObject View
# [5] Pane | 'ms-pbi://pbi.microsoft.com/Views/FloatingDialog/FloatingDialog.htm' | Internet Explorer_Server
# [6] Pane | '' |
# [7] Pane | 'Excel Workbook' |
# [28] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [29] Pane | '' | Shell Embedding
# [30] Pane | '' | Shell DocObject View
# [31] Pane | 'ms-pbi://pbi.microsoft.com/Views/KoForm.htm' | Internet Explorer_Server
# [32] Pane | '' |
# [33] Pane | 'Data source settings' |
# [34] Pane | 'Data source settings' |
# [65] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [66] Pane | '' | Chrome_WidgetWin_0
# [67] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html' | Chrome_WidgetWin_1
# [68] Pane | '' | Intermediate D3D Window
# [69] Pane | '' | Intermediate D3D Window
# [70] Pane | 'ms-pbi.pbi.microsoft.com/minerva/reportView.html - Web content' | BrowserRootView
# [71] Pane | '' | NonClientView
# [72] Pane | '' | EmbeddedBrowserTabRootView
# [73] Pane | '' | EmbeddedBrowserFrameView
# [74] Pane | '' | BrowserView
# [75] Pane | '' | TopContainerView
# [76] Pane | '' | SidebarContentsSplitView
# [77] Pane | '' | SidebarContentsSplitView
# [78] Pane | '' | View
# [114] Pane | '' | root-246 bottomBarContainer
# [196] Pane | '' | exploration
# [726] Pane | '' | fieldListPane
# [800] Pane | '' | EmbeddedBrowserDownloadView
# [801] Pane | '' | TopContainerOverlayView
# [802] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [803] Pane | '' | Chrome_WidgetWin_0
# [804] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html' | Chrome_WidgetWin_1
# [805] Pane | '' | Intermediate D3D Window
# [806] Pane | '' | Intermediate D3D Window
# [807] Pane | 'ms-pbi.pbi.microsoft.com/minerva/dataExploreView.html - Web content' | BrowserRootView
# [808] Pane | '' | NonClientView
# [809] Pane | '' | EmbeddedBrowserTabRootView
# [810] Pane | '' | EmbeddedBrowserFrameView
# [811] Pane | '' | BrowserView
# [812] Pane | '' | TopContainerView
# [813] Pane | '' | SidebarContentsSplitView
# [814] Pane | '' | SidebarContentsSplitView
# [815] Pane | '' | View
# [847] Pane | '' | root-246 bottomBarContainer
# [927] Pane | '' | fieldListPane
# [1000] Pane | '' | EmbeddedBrowserDownloadView
# [1001] Pane | '' | TopContainerOverlayView
# [1002] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1003] Pane | '' | Chrome_WidgetWin_0
# [1004] Pane | 'ms-pbi.pbi.microsoft.com/minerva/modelView.html' | Chrome_WidgetWin_1
# [1005] Pane | '' | Intermediate D3D Window
# [1006] Pane | '' | Intermediate D3D Window
# [1007] Pane | 'ms-pbi.pbi.microsoft.com/minerva/modelView.html - Web content' | BrowserRootView
# [1008] Pane | '' | NonClientView
# [1009] Pane | '' | EmbeddedBrowserTabRootView
# [1010] Pane | '' | EmbeddedBrowserFrameView
# [1011] Pane | '' | BrowserView
# [1012] Pane | '' | TopContainerView
# [1013] Pane | '' | SidebarContentsSplitView
# [1014] Pane | '' | SidebarContentsSplitView
# [1015] Pane | '' | View
# [1047] Pane | '' | root-246 bottomBarContainer
# [1350] Pane | '' | EmbeddedBrowserDownloadView
# [1351] Pane | '' | TopContainerOverlayView
# [1352] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1353] Pane | '' | Chrome_WidgetWin_0
# [1354] Pane | 'ms-pbi.pbi.microsoft.com/minerva/daxQueryView.html' | Chrome_WidgetWin_1
# [1355] Pane | '' | Intermediate D3D Window
# [1356] Pane | '' | Intermediate D3D Window
# [1357] Pane | 'ms-pbi.pbi.microsoft.com/minerva/daxQueryView.html - Web content' | BrowserRootView
# [1358] Pane | '' | NonClientView
# [1359] Pane | '' | EmbeddedBrowserTabRootView
# [1360] Pane | '' | EmbeddedBrowserFrameView
# [1361] Pane | '' | BrowserView
# [1362] Pane | '' | TopContainerView
# [1363] Pane | '' | SidebarContentsSplitView
# [1364] Pane | '' | SidebarContentsSplitView
# [1365] Pane | '' | View
# [1398] Pane | '' | root-210 bottomBarContainer
# [1524] Window | 'Run DAX queries on your model' | mat-mdc-dialog-container mdc-dialog cdk-dialog-container mdc-dialog--open _mat-animation-noopable
# [1538] Pane | '' | EmbeddedBrowserDownloadView
# [1539] Pane | '' | TopContainerOverlayView
# Controles en la ventana 'Excel Workbook':
# [0] Pane | '' | WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | Shell Embedding
# [2] Pane | '' | Shell DocObject View
# [3] Pane | 'ms-pbi://pbi.microsoft.com/Views/FloatingDialog/FloatingDialog.htm' | Internet Explorer_Server
# [4] Pane | '' |
# [5] Pane | 'Excel Workbook' |
# [6] Text | 'Excel Workbook' |
# [7] Button | 'Close' |
# [8] List | '' |
# [9] RadioButton | 'Basic' |
# [10] Group | 'Basic' |
# [11] Text | 'Basic' |
# [12] RadioButton | 'Advanced' |
# [13] Group | 'Advanced' |
# [14] Text | 'Advanced' |
# [15] Text | 'File path' |
# [16] Edit | 'File path' |
# [17] Button | 'Browse' |
# [18] Text | 'Browse...' |
# [19] Text | 'Open file as' |
# [20] ComboBox | 'Open file as Excel Workbook' |
# [21] Text | 'Excel Workbook' |
# [22] Button | 'OK' |
# [23] Text | 'OK' |
# [24] Button | 'Cancel' |
# [25] Text | 'Cancel' |
# ✅ Ruta escrita: C:\Users\Administrator\DMV Automation\Archivos Consolidados\testUser - Consolidado.xlsx
# ✅ Click en botón 'OK'.
# ✅ Ventana 'Data source settings' cerrada.
# ✅ Botón 'Refresh' clickeado correctamente.
# ✅ Tab 'File' clickeado.
# ✅ Tab 'Save as' clickeado correctamente.
# ✅ Botón 'Browse this device' clickeado correctamente.
# [📁] Esperando ventana 'Save As' (como hijo)...
# [✓] Ventana 'Save As' detectada.
# [✓] Nombre de archivo seteado: testUser - Empower BI
# [✓] Carpeta destino seteada: C:\Users\Administrator\OneDrive\Empower BI Archivos\Entregables
# [✓] Click en 'Save' exitoso.
# [↪] Confirmación de reemplazo aceptada.
# [✅] Archivo 'testUser - Empower BI' guardado correctamente.
# ✅ Botón 'Publish' clickeado correctamente.
# 🔍 Buscando ventanas hijas del proceso Power BI...
# [0] Dialog | '' | class: WindowsForms10.Window.20008.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [2] Pane | '' | class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [3] Pane | '' | class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [4] Pane | '' | class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [5] TitleBar | '' | class:
#
# ✅ Dialog encontrado. Listando todos los descendants...
#
# [0] Pane | '' | class: WindowsForms10.Window.8.app.0.10f7c6e_r7_ad1
# [1] Pane | '' | class: Chrome_WidgetWin_0
# [2] Pane | 'ms-pbi.pbi.microsoft.com/minerva/desktopDialogHost.html' | class: Chrome_WidgetWin_1
# [3] Pane | '' | class: Intermediate D3D Window
# [4] Pane | '' | class: Intermediate D3D Window
# [5] Pane | 'ms-pbi.pbi.microsoft.com/minerva/desktopDialogHost.html - Web content' | class: BrowserRootView
# [6] Pane | '' | class: NonClientView
# [7] Pane | '' | class: EmbeddedBrowserTabRootView
# [8] Pane | '' | class: EmbeddedBrowserFrameView
# [9] Pane | '' | class: BrowserView
# [10] Pane | '' | class: TopContainerView
# [11] Pane | '' | class: SidebarContentsSplitView
# [12] Pane | '' | class: SidebarContentsSplitView
# [13] Pane | '' | class: View
# [14] Document | '' | class:
# [15] GroupBox | '' | class: site-default theme-default v1 themeableElement
# [16] GroupBox | '' | class: cdk-live-announcer-element cdk-visually-hidden
# [17] GroupBox | 'Publish to Power BI' | class: mat-mdc-dialog-container mdc-dialog cdk-dialog-container mdc-dialog--open _mat-animation-noopable
# [18] Static | 'Publish to Power BI' | class: mat-mdc-dialog-title mdc-dialog__title mat-dialog-title
# [19] Button | 'Close Dialog' | class:
# [20] Image | '' | class:
# [21] Static | 'Select a destination' | class:
# [22] Static | '' | class:
# [23] Edit | '￼' | class: searchText pbi-focus-outline ng-untouched ng-pristine ng-valid
# [24] ListBox | 'Workspaces' | class: mat-selection-list mat-list-base
# [25] ListItem | 'CoderHouse - DA' | class: mat-list-item mat-list-option mat-focus-indicator mat-accent
# [26] ListItem | 'dgh' | class: mat-list-item mat-list-option mat-focus-indicator mat-accent
# [27] ListItem | 'My workspace' | class: mat-list-item mat-list-option mat-focus-indicator mat-accent
# [28] ListItem | 'zdc' | class: mat-list-item mat-list-option mat-focus-indicator mat-accent
# [29] Button | 'Select' | class: pbi-fluent-button primary primaryBtn
# [30] Button | 'Cancel' | class: pbi-fluent-button
# [31] Pane | '' | class: EmbeddedBrowserDownloadView
# [32] Pane | '' | class: TopContainerOverlayView
# 🔍 Buscando ventanas hijas del proceso Power BI...
# ✅ Ventana Dialog detectada.
# ✅ Workspace 'dgh' seleccionado.
# ✅ Botón 'Select' clickeado.
# ⏳ Esperando posible ventana de reemplazo...
# ✅ Botón 'Replace' clickeado.
# ⏳ Esperando mensaje 'Success!' y link para abrir en Power BI...
# ✅ Link 'Open 'testUser - Empower BI.pbix' in Power BI' clickeado.
#
# 🔸 STDERR:
